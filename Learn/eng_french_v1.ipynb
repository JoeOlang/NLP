# %% [markdown]
# <a href="https://colab.research.google.com/github/JoeOlang/NLP/blob/main/Learn/eng_french_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import unicodedata
import re
import math
import psutil
import time
import datetime
from io import open
import random
from random import shuffle
import argparse
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import torch.cuda

"""this line clears sys to allow for argparse to work as gradient clipper"""
import sys; sys.argv=['']; del sys

# %%
use_cuda = torch.cuda.is_available()
print(use_cuda)
# Out:
# True

# %%
"""This function converts a Unicode string to plain ASCII 
from https://stackoverflow.com/a/518232/2809427"""
def uniToAscii(sentence):
    return ''.join(
        c for c in unicodedata.normalize('NFD', sentence)
        if unicodedata.category(c) != 'Mn'
    )


"""Lowercase, trim, and remove non-letter characters (from pytorch)"""
def normalizeString(s):
    s = re.sub(r" ##AT##-##AT## ", r" ", s)
    s = uniToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s   

  
"""Denote patterns that sentences must start with to be kept in dataset. 
Can be changed if desired (from pytorch)"""
eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)

# %%
"""Filters each input-output pair, keeping sentences that are less than max_length 
if start_filter is true, also filters out sentences that don't start with eng_prefixes"""
def filterPair(p, max_length, start_filter):
    filtered = len(p[0].split(' ')) < max_length and \
        len(p[1].split(' ')) < max_length 
    if start_filter:
        return filtered and p[1].startswith(eng_prefixes)
    else:
        return filtered

"""Filters all of the input-output language pairs in the dataset using filterPair 
for each pair (from pytorch)"""
def filterPairs(pairs, max_length, start_filter):
    return [pair for pair in pairs if filterPair(pair, max_length, start_filter)]

# %%
"""start of sentence tag"""
SOS_token = 0

"""end of sentence tag"""
EOS_token = 1

"""unknown word tag (this is used to handle words that are not in our Vocabulary)"""
UNK_token = 2

# %%
"""Lang class, used to store the vocabulary of each language"""
class Lang:
    def __init__(self, language):
        self.language_name = language
        self.word_to_index = {"SOS":SOS_token, "EOS":EOS_token, "<UNK>":UNK_token}
        self.word_to_count = {}
        self.index_to_word = {SOS_token: "SOS", EOS_token: "EOS", UNK_token: "<UNK>"}
        self.vocab_size = 3
        self.cutoff_point = -1


    def countSentence(self, sentence):
        for word in sentence.split(' '):
            self.countWords(word)

    """counts the number of times each word appears in the dataset"""
    def countWords(self, word):
        if word not in self.word_to_count:
            self.word_to_count[word] = 1
        else:
            self.word_to_count[word] += 1

    """if the number of unique words in the dataset is larger than the
    specified max_vocab_size, creates a cutoff point that is used to
    leave infrequent words out of the vocabulary"""
    def createCutoff(self, max_vocab_size):
        word_freqs = list(self.word_to_count.values())
        word_freqs.sort(reverse=True)
        if len(word_freqs) > max_vocab_size:
            self.cutoff_point = word_freqs[max_vocab_size]

    """assigns each unique word in a sentence a unique index"""
    def addSentence(self, sentence):
        new_sentence = ''
        for word in sentence.split(' '):
            unk_word = self.addWord(word)
            if not new_sentence:
                new_sentence =unk_word
            else:
                new_sentence = new_sentence + ' ' + unk_word
        return new_sentence

    """assigns a word a unique index if not already in vocabulary
    and it appeaars often enough in the dataset
    (self.word_to_count is larger than self.cutoff_point)"""
    def addWord(self, word):
        if self.word_to_count[word] > self.cutoff_point:
            if word not in self.word_to_index:
                self.word_to_index[word] = self.vocab_size
                self.index_to_word[self.vocab_size] = word
                self.vocab_size += 1
            return word
        else:
            return self.index_to_word[2]

# %%
'''prepares both the input and output Lang classes from the passed dataset'''

def prepareLangs(lang1, lang2, file_path, reverse=False):
    print("Reading lines...")

    if len(file_path) == 2:
        lang1_lines = open(file_path[0], encoding='utf-8').\
            read().strip().split('\n')

        lang2_lines = open(file_path[1], encoding='utf-8').\
            read().strip().split('\n')

        if len(lang1_lines) != len(lang2_lines):
            print("Input and output text sizes do not align")
            print("Number of lang1 lines: %s " %len(lang1_lines))
            print("Number of lang2 lines: %s " %len(lang2_lines))
            quit()

        pairs = []

        for line in range(len(lang1_lines)):
            pairs.append([normalizeString(lang1_lines[line]),
                          normalizeString(lang2_lines[line])])            


    elif len(file_path) == 1:
        lines = open(file_path[0], encoding='utf-8').\
    	read().strip().split('\n')
        pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs
    
    
'''prepares both the input and output Lang classes from the passed dataset'''

def prepareLangs(lang1, lang2, file_path, reverse=False):
    print("Reading lines...")

    if len(file_path) == 2:
        lang1_lines = open(file_path[0], encoding='utf-8').\
            read().strip().split('\n')

        lang2_lines = open(file_path[1], encoding='utf-8').\
            read().strip().split('\n')

        if len(lang1_lines) != len(lang2_lines):
            print("Input and output text sizes do not align")
            print("Number of lang1 lines: %s " %len(lang1_lines))
            print("Number of lang2 lines: %s " %len(lang2_lines))
            quit()

        pairs = []

        for line in range(len(lang1_lines)):
            pairs.append([normalizeString(lang1_lines[line]),
                          normalizeString(lang2_lines[line])])            


    elif len(file_path) == 1:
        lines = open(file_path[0], encoding='utf-8').\
    	read().strip().split('\n')
        pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
"""completely prepares both input and output languages 
and returns cleaned and trimmed train and test pairs"""

def prepareData(lang1, lang2, file_path, max_vocab_size=50000, 
                reverse=False, trim=0, start_filter=False, perc_train_set=0.9, 
                print_to=None):
    
    input_lang, output_lang, pairs = prepareLangs(lang1, lang2, 
                                                  file_path, reverse)
    
    print("Read %s sentence pairs" % len(pairs))
    
    if print_to:
        with open(print_to,'a') as f:
            f.write("Read %s sentence pairs \n" % len(pairs))
    
    if trim != 0:
        pairs = filterPairs(pairs, trim, start_filter)
        print("Trimmed to %s sentence pairs" % len(pairs))
        if print_to:
            with open(print_to,'a') as f:
                f.write("Read %s sentence pairs \n" % len(pairs))

    print("Counting words...")
    for pair in pairs:
        input_lang.countSentence(pair[0])
        output_lang.countSentence(pair[1])


    input_lang.createCutoff(max_vocab_size)
    output_lang.createCutoff(max_vocab_size)

    pairs = [(input_lang.addSentence(pair[0]),output_lang.addSentence(pair[1])) 
             for pair in pairs]

    shuffle(pairs)
    
    train_pairs = pairs[:math.ceil(perc_train_set*len(pairs))]
    test_pairs = pairs[math.ceil(perc_train_set*len(pairs)):]

    print("Train pairs: %s" % (len(train_pairs)))
    print("Test pairs: %s" % (len(test_pairs)))
    print("Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):")
    print("%s, %s -> %s" % (input_lang.language_name, len(input_lang.word_to_count),
                            input_lang.vocab_size,))
    print("%s, %s -> %s" % (output_lang.language_name, len(output_lang.word_to_count), 
                            output_lang.vocab_size))
    print()

    if print_to:
        with open(print_to,'a') as f:
            f.write("Train pairs: %s" % (len(train_pairs)))
            f.write("Test pairs: %s" % (len(test_pairs)))
            f.write("Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):")
            f.write("%s, %s -> %s" % (input_lang.language_name, 
                                      len(input_lang.word_to_count),
                                      input_lang.vocab_size,))
            f.write("%s, %s -> %s \n" % (output_lang.language_name, len(output_lang.word_to_count), 
                            output_lang.vocab_size))
        
    return input_lang, output_lang, train_pairs, test_pairs

# %%
"""converts a sentence to one hot encoding vectors - pytorch allows us to just
use the number corresponding to the unique index for that word,
rather than a complete one hot encoding vector for each word"""
def indexesFromSentence(lang, sentence):
    indexes = []
    for word in sentence.split(' '):
        try:
            indexes.append(lang.word_to_index[word])
        except:
            indexes.append(lang.word_to_index["<UNK>"])
    return indexes


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    result = torch.LongTensor(indexes).view(-1)
    if use_cuda:
        return result.cuda()
    else:
        return result
      
"""converts a pair of sentence (input and target) to a pair of tensors"""
def tensorsFromPair(input_lang, output_lang, pair):
    input_variable = tensorFromSentence(input_lang, pair[0])
    target_variable = tensorFromSentence(output_lang, pair[1])
    return (input_variable, target_variable)
  

"""converts from tensor of one hot encoding vector indices to sentence"""
def sentenceFromTensor(lang, tensor):
    raw = tensor.data
    words = []
    for num in raw:
        words.append(lang.index_to_word[num.item()])
    return ' '.join(words)

# %%
"""seperates data into batches of size batch_size"""
def batchify(data, input_lang, output_lang, batch_size, shuffle_data=True):
    if shuffle_data == True:
        shuffle(data)
    number_of_batches = len(data) // batch_size
    batches = list(range(number_of_batches))
    longest_elements = list(range(number_of_batches))
    
    for batch_number in range(number_of_batches):
        longest_input = 0
        longest_target = 0
        input_variables = list(range(batch_size))
        target_variables = list(range(batch_size))
        index = 0      
        for pair in range((batch_number*batch_size),((batch_number+1)*batch_size)):
            input_variables[index], target_variables[index] = tensorsFromPair(input_lang, output_lang, data[pair])
            if len(input_variables[index]) >= longest_input:
                longest_input = len(input_variables[index])
            if len(target_variables[index]) >= longest_target:
                longest_target = len(target_variables[index])
            index += 1
        batches[batch_number] = (input_variables, target_variables)
        longest_elements[batch_number] = (longest_input, longest_target)
    return batches , longest_elements, number_of_batches


"""pads batches to allow for sentences of variable lengths to be computed in parallel"""
def pad_batch(batch):
    padded_inputs = torch.nn.utils.rnn.pad_sequence(batch[0],padding_value=EOS_token)
    padded_targets = torch.nn.utils.rnn.pad_sequence(batch[1],padding_value=EOS_token)
    return (padded_inputs, padded_targets)

# %%
class EncoderRNN(nn.Module):
	def __init__(self,input_size,hidden_size,layers=1,dropout=0.1,
               bidirectional=True):
		super(EncoderRNN, self).__init__()

		if bidirectional:
			self.directions = 2
		else:
			self.directions = 1
		self.input_size = input_size
		self.hidden_size = hidden_size
		self.num_layers = layers
		self.dropout = dropout
		self.embedder = nn.Embedding(input_size,hidden_size)
		self.dropout = nn.Dropout(dropout)
		self.lstm = nn.LSTM(input_size=hidden_size,hidden_size=hidden_size,
                        num_layers=layers,dropout=dropout,
                        bidirectional=bidirectional,batch_first=False)
		self.fc = nn.Linear(hidden_size*self.directions, hidden_size)

	def forward(self, input_data, h_hidden, c_hidden):
		embedded_data = self.embedder(input_data)
		embedded_data = self.dropout(embedded_data)
		hiddens, outputs = self.lstm(embedded_data, (h_hidden, c_hidden))

		return hiddens, outputs

	"""creates initial hidden states for encoder corresponding to batch size"""
	def create_init_hiddens(self, batch_size):
		h_hidden = Variable(torch.zeros(self.num_layers*self.directions, 
                                    batch_size, self.hidden_size))
		c_hidden = Variable(torch.zeros(self.num_layers*self.directions, 
                                    batch_size, self.hidden_size))
		if torch.cuda.is_available():
			return h_hidden.cuda(), c_hidden.cuda()
		else:
			return h_hidden, c_hidden

# %%
class DecoderAttn(nn.Module):
	def __init__(self, hidden_size, output_size, layers=1, dropout=0.1, bidirectional=True):
		super(DecoderAttn, self).__init__()

		if bidirectional:
			self.directions = 2
		else:
			self.directions = 1
		self.output_size = output_size
		self.hidden_size = hidden_size
		self.num_layers = layers
		self.dropout = dropout
		self.embedder = nn.Embedding(output_size,hidden_size)
		self.dropout = nn.Dropout(dropout)
		self.score_learner = nn.Linear(hidden_size*self.directions, 
                                   hidden_size*self.directions)
		self.lstm = nn.LSTM(input_size=hidden_size,hidden_size=hidden_size,
                        num_layers=layers,dropout=dropout,
                        bidirectional=bidirectional,batch_first=False)
		self.context_combiner = nn.Linear((hidden_size*self.directions)
                                      +(hidden_size*self.directions), hidden_size)
		self.tanh = nn.Tanh()
		self.output = nn.Linear(hidden_size, output_size)
		self.soft = nn.Softmax(dim=1)
		self.log_soft = nn.LogSoftmax(dim=1)


	def forward(self, input_data, h_hidden, c_hidden, encoder_hiddens):

		embedded_data = self.embedder(input_data)
		embedded_data = self.dropout(embedded_data)	
		batch_size = embedded_data.shape[1]
		hiddens, outputs = self.lstm(embedded_data, (h_hidden, c_hidden))	
		top_hidden = outputs[0].view(self.num_layers,self.directions,
                                 hiddens.shape[1],
                                 self.hidden_size)[self.num_layers-1]
		top_hidden = top_hidden.permute(1,2,0).contiguous().view(batch_size,-1, 1)

		prep_scores = self.score_learner(encoder_hiddens.permute(1,0,2))
		scores = torch.bmm(prep_scores, top_hidden)
		attn_scores = self.soft(scores)
		con_mat = torch.bmm(encoder_hiddens.permute(1,2,0),attn_scores)
		h_tilde = self.tanh(self.context_combiner(torch.cat((con_mat,
                                                         top_hidden),dim=1)
                                              .view(batch_size,-1)))
		pred = self.output(h_tilde)
		pred = self.log_soft(pred)

		
		return pred, outputs

# %%
'''Performs training on a single batch of training data. Computing the loss 
according to the passed loss_criterion and back-propagating on this loss.'''

def train_batch(input_batch, target_batch, encoder, decoder, 
                encoder_optimizer, decoder_optimizer, loss_criterion):
	encoder_optimizer.zero_grad()
	decoder_optimizer.zero_grad()
	loss = 0
	enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(input_batch.shape[1])

	enc_hiddens, enc_outputs = encoder(input_batch, enc_h_hidden, enc_c_hidden)

	decoder_input = Variable(torch.LongTensor(1,input_batch.shape[1]).
                           fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
					else Variable(torch.LongTensor(1,input_batch.shape[1]).
                        fill_(output_lang.word_to_index.get("SOS")))

	dec_h_hidden = enc_outputs[0]
	dec_c_hidden = enc_outputs[1]
	
	for i in range(target_batch.shape[0]):
		pred, dec_outputs = decoder(decoder_input, dec_h_hidden, 
                                dec_c_hidden, enc_hiddens)

		decoder_input = target_batch[i].view(1,-1)
		dec_h_hidden = dec_outputs[0]
		dec_c_hidden = dec_outputs[1]
		
		loss += loss_criterion(pred,target_batch[i])


	loss.backward()

	torch.nn.utils.clip_grad_norm_(encoder.parameters(),args.clip)
	torch.nn.utils.clip_grad_norm_(decoder.parameters(),args.clip)

	encoder_optimizer.step()
	decoder_optimizer.step()

	return loss.item() / target_batch.shape[0]

# %%
'''Performs a complete epoch of training through all of the training_batches'''

def train(train_batches, encoder, decoder, encoder_optimizer, decoder_optimizer, loss_criterion):

	round_loss = 0
	i = 1
	for batch in train_batches:
		i += 1
		(input_batch, target_batch) = pad_batch(batch)
		batch_loss = train_batch(input_batch, target_batch, encoder, decoder, encoder_optimizer, decoder_optimizer, loss_criterion)
		round_loss += batch_loss

	return round_loss / len(train_batches)

# %%
'''Evaluates the loss on a single batch of test data. Computing the loss 
according to the passed loss_criterion. Does not perform back-prop'''

def test_batch(input_batch, target_batch, encoder, decoder, loss_criterion):
	
	loss = 0

	#create initial hidde state for encoder
	enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(input_batch.shape[1])

	enc_hiddens, enc_outputs = encoder(input_batch, enc_h_hidden, enc_c_hidden)

	decoder_input = Variable(torch.LongTensor(1,input_batch.shape[1]).
                           fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
					else Variable(torch.LongTensor(1,input_batch.shape[1]).
                        fill_(output_lang.word_to_index.get("SOS")))
	dec_h_hidden = enc_outputs[0]
	dec_c_hidden = enc_outputs[1]
	
	for i in range(target_batch.shape[0]):
		pred, dec_outputs = decoder(decoder_input, dec_h_hidden, dec_c_hidden, enc_hiddens)

		topv, topi = pred.topk(1,dim=1)
		ni = topi.view(1,-1)
		
		decoder_input = ni
		dec_h_hidden = dec_outputs[0]
		dec_c_hidden = dec_outputs[1]

		loss += loss_criterion(pred,target_batch[i])
		
	return loss.item() / target_batch.shape[0]

# %%
'''Computes the loss value over all of the test_batches'''

def test(test_batches, encoder, decoder, loss_criterion):

	with torch.no_grad():
		test_loss = 0

		for batch in test_batches:
			(input_batch, target_batch) = pad_batch(batch)
			batch_loss = test_batch(input_batch, target_batch, encoder, decoder, loss_criterion)
			test_loss += batch_loss

	return test_loss / len(test_batches)

# %%
'''Returns the predicted translation of a given input sentence. Predicted
translation is trimmed to length of cutoff_length argument'''

def evaluate(encoder, decoder, sentence, cutoff_length):
	with torch.no_grad():
		input_variable = tensorFromSentence(input_lang, sentence)
		input_variable = input_variable.view(-1,1)
		enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(1)

		enc_hiddens, enc_outputs = encoder(input_variable, enc_h_hidden, enc_c_hidden)

		decoder_input = Variable(torch.LongTensor(1,1).fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
						else Variable(torch.LongTensor(1,1).fill_(output_lang.word_to_index.get("SOS")))
		dec_h_hidden = enc_outputs[0]
		dec_c_hidden = enc_outputs[1]

		decoded_words = []

		for di in range(cutoff_length):
			pred, dec_outputs = decoder(decoder_input, dec_h_hidden, dec_c_hidden, enc_hiddens)

			topv, topi = pred.topk(1,dim=1)
			ni = topi.item()
			if ni == output_lang.word_to_index.get("EOS"):
				decoded_words.append('<EOS>')
				break
			else:
				decoded_words.append(output_lang.index_to_word[ni])

			decoder_input = Variable(torch.LongTensor(1,1).fill_(ni).cuda()) if use_cuda \
							else Variable(torch.LongTensor(1,1).fill_(ni))
			dec_h_hidden = dec_outputs[0]
			dec_c_hidden = dec_outputs[1]

		output_sentence = ' '.join(decoded_words)
    
		return output_sentence

# %%
'''Evaluates prediction translations for a specified number (n) of sentences
chosen randomly from a list of passed sentence pairs. Returns three sentences
in the format:
                  > input sentence
                  = correct translation
                  < predicted translation'''

def evaluate_randomly(encoder, decoder, pairs, n=2, trim=100):
	for i in range(n):
		pair = random.choice(pairs)
		print('>', pair[0])
		print('=', pair[1])
		output_sentence = evaluate(encoder, decoder, pair[0],cutoff_length=trim)
		print('<', output_sentence)
		print('')    
		if create_txt:
			f = open(print_to, 'a')
			f.write("\n \
				> %s \n \
				= %s \n \
				< %s \n" % (pair[0], pair[1], output_sentence))
			f.close()

# %%
'''Used to plot the progress of training. Plots the loss value vs. time'''
def showPlot(times, losses, fig_name):
    x_axis_label = 'Minutes'
    colors = ('red','blue')
    if max(times) >= 120:
    	times = [mins/60 for mins in times]
    	x_axis_label = 'Hours'
    i = 0
    for key, losses in losses.items():
    	if len(losses) > 0:
    		plt.plot(times, losses, label=key, color=colors[i])
    		i += 1
    plt.legend(loc='upper left')
    plt.xlabel(x_axis_label)
    plt.ylabel('Loss')
    plt.title('Training Results')
    plt.savefig(fig_name+'.png')
    plt.close('all')
    
'''prints the current memory consumption'''
def mem():
	if use_cuda:
		mem = torch.cuda.memory_allocated()/1e7
	else:
		mem = psutil.cpu_percent()
	print('Current mem usage:')
	print(mem)
	return "Current mem usage: %s \n" % (mem)

'''converts a time measurement in seconds to hours'''
def asHours(s):
	m = math.floor(s / 60)
	h = math.floor(m / 60)
	s -= m * 60
	m -= h * 60
	return '%dh %dm %ds' % (h, m, s)

# %%
'''The master function that trains the model. Evlautes progress on the train set
(if present) and also records the progress of training in both a txt file and
a png graph. Also can save the weights of both the Encoder and Decoder 
for future use.'''

def train_and_test(epochs, test_eval_every, plot_every, learning_rate, 
                   lr_schedule, train_pairs, test_pairs, input_lang, 
                   output_lang, batch_size, test_batch_size, encoder, decoder, 
                   loss_criterion, trim, save_weights):
	
	times = []
	losses = {'train set':[], 'test set': []}

	test_batches, longest_seq, n_o_b = batchify(test_pairs, input_lang, 
                                              output_lang, test_batch_size, 
                                              shuffle_data=False)

	start = time.time()
	for i in range(1,epochs+1):
    
		'''adjust the learning rate according to the learning rate schedule
		specified in lr_schedule'''
		if i in lr_schedule.keys():
			learning_rate /= lr_schedule.get(i)


		encoder.train()
		decoder.train()

		encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
		decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)

		batches, longest_seq, n_o_b = batchify(train_pairs, input_lang, 
                                           output_lang, batch_size, 
                                           shuffle_data=True)
		train_loss = train(batches, encoder, decoder, encoder_optimizer, 
                       decoder_optimizer, loss_criterion)
		
		now = time.time()
		print("Iter: %s \nLearning Rate: %s \nTime: %s \nTrain Loss: %s \n" 
          % (i, learning_rate, asHours(now-start), train_loss))

		if create_txt:
			with open(print_to, 'a') as f:
				f.write("Iter: %s \nLeaning Rate: %s \nTime: %s \nTrain Loss: %s \n" \
					% (i, learning_rate, asHours(now-start), train_loss))

		if i % test_eval_every == 0:
			if test_pairs:
				test_loss = test(test_batches, encoder, decoder, criterion)
				print("Test set loss: %s" % (test_loss))
				if create_txt:
					with open(print_to, 'a') as f:
						f.write("Test Loss: %s \n" % (test_loss))
				evaluate_randomly(encoder, decoder, test_pairs, trim)
			else:
				evaluate_randomly(encoder, decoder, train_pairs, trim)

		if i % plot_every == 0:
			times.append((time.time()-start)/60)
			losses['train set'].append(train_loss)
			if test_pairs:
				losses['test set'].append(test_loss)
			showPlot(times, losses, output_file_name)
			if save_weights:
				torch.save(encoder.state_dict(), output_file_name+'_enc_weights.pt')
				torch.save(decoder.state_dict(), output_file_name+'_dec_weights.pt')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-72bbe44a-ac6f-4f4d-a188-1db2c2307afa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72bbe44a-ac6f-4f4d-a188-1db2c2307afa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving eng-fra.txt to eng-fra.txt

# %%
ls
# Out:
# eng-fra.txt  sample_data/

# %%
"""PROVIDE INFORMATION ON THE DATASET AND DATASET CLEANING"""

input_lang_name = 'fre'
output_lang_name = 'en'

"""name of your dataset"""
dataset = 'orig'

"""file path of dataset in the form of a tuple. If translated sentences are
stored in two files, this tuple will have two elements"""
raw_data_file_path = ('eng-fra.txt',)

"""True if you want to reverse the order of the sentence pairs. For example, 
in our dataset the sentence pairs list the English sentence first followed by
the French translation. But we want to translate from French to English,
so we set reverse as True."""
reverse=True

"""Remove sentences from dataset that are longer than trim (in either language)"""
trim = 10

"""max number of words in the vocabulary for both languages"""
max_vocab_size= 20000

"""if true removes sentences from the dataset that don't start with eng_prefixes.
Typically will want to use False, but implemented to compare results with Pytorch
tutorial. Can also change the eng_prefixes to prefixes of other languages or
other English prefixes. Just be sure that the prefixes apply to the OUTPUT
language (i.e. the language that the model is translating to NOT from)"""
start_filter = True

"""denotes what percentage of the data to use as training data. the remaining 
percentage becomes test data. Typically want to use 0.8-0.9. 1.0 used here to 
compare with PyTorch results where no test set was utilized"""
perc_train_set = 1.0

# %%
"""OUTPUT OPTIONS"""

"""denotes how often to evaluate a loss on the test set and print
sample predictions on the test set.
if no test set, simply prints sample predictions on the train set."""
test_eval_every = 1

"""denotes how often to plot the loss values of train and test (if applicable)"""
plot_every = 1

"""if true creates a txt file of the output"""
create_txt = True

"""if true saves the encoder and decoder weights to seperate .pt files for later use"""
save_weights = False

# %%
"""HYPERPARAMETERS: FEEL FREE TO PLAY WITH THESE TO TRY TO ACHIEVE BETTER RESULTS"""

"""signifies whether the Encoder and Decoder should be bidirectional LSTMs or not"""
bidirectional = True
if bidirectional:
	directions = 2
else:
	directions = 1

"""number of layers in both the Encoder and Decoder"""
layers = 2

"""Hidden size of the Encoder and Decoder"""
hidden_size = 440

"""Dropout value for Encoder and Decoder"""
dropout = 0.2

"""Training set batch size"""
batch_size = 32

"""Test set batch size"""
test_batch_size = 32

"""number of epochs (full passes through the training data)"""
epochs = 100

"""Initial learning rate"""
learning_rate= 1

"""Learning rate schedule. Signifies by what factor to divide the learning rate
at a certain epoch. For example {5:10} would divide the learning rate by 10
before the 5th epoch and {5:10, 10:100} would divide the learning rate by 10
before the 5th epoch and then again by 100 before the 10th epoch"""
lr_schedule = {}

"""loss criterion, see https://pytorch.org/docs/stable/nn.html for other options"""
criterion = nn.NLLLoss()

# %%
"""******************************************************************
********************NO NEED TO ALTER ANYTHING BELOW******************
******************************************************************"""

use_cuda = torch.cuda.is_available()


"""for plotting of the loss"""
plt.switch_backend('agg')

output_file_name = "testdata.%s_trim.%s_vocab.%s_directions.%s_layers.%s_hidden.%s_dropout.%s_learningrate.%s_batch.%s_epochs.%s" % (dataset,trim,max_vocab_size,directions,layers,hidden_size,dropout,learning_rate,batch_size,epochs)

if create_txt:
	print_to = output_file_name+'.txt'
	with open(print_to, 'w+') as f:
		f.write("Starting Training \n")
else:
	print_to = None

input_lang, output_lang, train_pairs, test_pairs = prepareData(
    input_lang_name, output_lang_name, raw_data_file_path, 
    max_vocab_size=max_vocab_size, reverse=reverse, trim=trim, 
    start_filter=start_filter, perc_train_set=perc_train_set, print_to=print_to)
print('Train Pairs #')
print(len(train_pairs))


"""for gradient clipping from 
https://github.com/pytorch/examples/blob/master/word_language_model/main.py"""
parser = argparse.ArgumentParser(description='PyTorch Wikitext-2 RNN/LSTM Language Model')
parser.add_argument('--clip', type=float, default=0.25,
                    help='gradient clipping')
args = parser.parse_args()

mem()

if create_txt:
	with open(print_to, 'a') as f:
		f.write("\nRandom Train Pair: %s \n\nRandom Test Pair: %s \n\n" 
            % (random.choice(train_pairs),random.choice(test_pairs) 
               if test_pairs else "None"))
		f.write(mem())


"""create the Encoder"""
encoder = EncoderRNN(input_lang.vocab_size, hidden_size, layers=layers, 
                     dropout=dropout, bidirectional=bidirectional)

"""create the Decoder"""
decoder = DecoderAttn(hidden_size, output_lang.vocab_size, layers=layers, 
                      dropout=dropout, bidirectional=bidirectional)

print('Encoder and Decoder Created')
mem()

if use_cuda:
	print('Cuda being used')
	encoder = encoder.cuda()
	decoder = decoder.cuda()

print('Number of epochs: '+str(epochs))

if create_txt:
	with open(print_to, 'a') as f:
		f.write('Encoder and Decoder Created\n')
		f.write(mem())
		f.write("Number of epochs %s \n" % (epochs))

train_and_test(epochs, test_eval_every, plot_every, learning_rate, lr_schedule, 
               train_pairs, test_pairs, input_lang, output_lang, batch_size, 
               test_batch_size, encoder, decoder, criterion, trim, save_weights)
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 10853 sentence pairs
# Counting words...
# Train pairs: 10853
# Test pairs: 0
# Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):
# en, 4487 -> 4490
# fre, 2923 -> 2926
#
# Train Pairs #
# 10853
# Current mem usage:
# 0.0
# Current mem usage:
# 0.0
# Encoder and Decoder Created
# Current mem usage:
# 0.0
# Cuda being used
# Number of epochs: 100
# Current mem usage:
# 8.9055744
# Iter: 1
# Learning Rate: 1
# Time: 0h 0m 15s
# Train Loss: 2.6234307481358763
#
# > elles sont tres intelligentes .
# = they re very smart .
# < we re not the . <EOS>
#
# > nous ne nous y rendons pas .
# = we re not going .
# < we re not the . <EOS>
#
# > je ne suis pas matinal .
# = i am not a morning person .
# < i m not to you you . <EOS>
#
# > je suis plutot occupe .
# = i m rather busy .
# < i m not to you you . <EOS>
#
# > tu es un etre mauvais .
# = you are a bad person .
# < you re not the . <EOS>
#
# > vous etes incroyable .
# = you re incredible .
# < you re very . <EOS>
#
# > vous etes extraverti .
# = you re extroverted .
# < you re very . <EOS>
#
# > vous etes respecte de tous .
# = you re respected by everybody .
# < you re not the the . <EOS>
#
# > elles sont juste pour vous .
# = they re just for you .
# < they re not the . <EOS>
#
# > je ne suis pas autorisee a vous aider .
# = i m not allowed to help you .
# < i m not not you you . <EOS>
#
# Iter: 2
# Learning Rate: 1
# Time: 0h 0m 30s
# Train Loss: 1.9964881815077302
#
# > vous n etes pas si interessantes .
# = you re not that interesting .
# < you re not t ? . <EOS>
#
# > vous n etes pas de mes amis .
# = you re no friend of mine .
# < you re not to to as as . <EOS>
#
# > vous etes un fauteur de trouble .
# = you are a troublemaker .
# < you re a a a the . <EOS>
#
# > j ai dix huit ans .
# = i m years old .
# < i m to to to to i of the . <EOS>
#
# > je n entrerai pas en competition .
# = i m not going to compete .
# < i m not not to to a . <EOS>
#
# > il a peur de son ombre .
# = he is afraid of his own shadow .
# < he s to to the the of . <EOS>
#
# > nous sommes de retour tot .
# = we re back early .
# < we re all to to the the the . <EOS>
#
# > elle a environ mon age .
# = she is about my age .
# < she is to to of a a . <EOS>
#
# > il n enfreint pas la loi .
# = he s not breaking the law .
# < he s not a a a a a a a a . <EOS>
#
# > je n en ai pas encore termine .
# = i m not done yet .
# < i m not to to as as . <EOS>
#
# Iter: 3
# Learning Rate: 1
# Time: 0h 0m 45s
# Train Loss: 1.7750259309704288
#
# > il est en route .
# = he s on his way .
# < he s a good . <EOS>
#
# > vous n etes pas tom .
# = you aren t tom .
# < you re not t t . <EOS>
#
# > elle cria a l aide .
# = she screamed for help .
# < she s him of him . <EOS>
#
# > c est un jeune homme d affaires prometteur .
# = he is a promising young businessman .
# < he s a a good his of his . <EOS>
#
# > cela m intrigue .
# = i m intrigued .
# < i m going to be this . <EOS>
#
# > il est pere de trois enfants .
# = he is the father of three children .
# < he s very to my the the the the . <EOS>
#
# > je suis heureux de vous avoir invitees .
# = i m glad i invited you .
# < i m sorry i i sorry you . <EOS>
#
# > ils sont tous semblables .
# = they are all alike .
# < they re all all all all . <EOS>
#
# > je ne suis pas bon a ca .
# = i m not good at this .
# < i m not not to that . <EOS>
#
# > il commence a avoir les foies .
# = he s getting cold feet .
# < he s always to him . <EOS>
#
# Iter: 4
# Learning Rate: 1
# Time: 0h 1m 0s
# Train Loss: 1.6012003530091596
#
# > vous etes fort attirants .
# = you re very attractive .
# < you re very very good . <EOS>
#
# > desole si je vous ai fait peur .
# = i m sorry if i scared you .
# < i m glad glad you . <EOS>
#
# > nous ne sommes pas impliques .
# = we re not involved .
# < we re not not yet . <EOS>
#
# > je suis analphabete .
# = i m illiterate .
# < i m in the the little . <EOS>
#
# > nous sommes quittes .
# = we are even .
# < we re in a good . <EOS>
#
# > elle prend du poids .
# = she is gaining weight .
# < she is him in the the his . <EOS>
#
# > il est assis en salle d attente .
# = he s sitting in the waiting room .
# < he is in his his his . <EOS>
#
# > elle est sympathique avec tout le monde .
# = she is gracious to everyone .
# < she is in the his his his . <EOS>
#
# > vous etes fort curieuse .
# = you re very curious .
# < you re very very good . <EOS>
#
# > tu es une puritaine .
# = you re a prude .
# < you re a good liar . <EOS>
#
# Iter: 5
# Learning Rate: 1
# Time: 0h 1m 15s
# Train Loss: 1.4593309745363465
#
# > vous etes jolie .
# = you re pretty .
# < you re very good . <EOS>
#
# > vous n etes pas habille .
# = you re not dressed .
# < you re not good yet . <EOS>
#
# > je vais me detendre .
# = i m going to relax .
# < i m going to be it . <EOS>
#
# > vous entendez des choses .
# = you are hearing things .
# < you re going to go . <EOS>
#
# > vous n etes pas satisfait si ?
# = you re not satisfied are you ?
# < you re not aren t you ? <EOS>
#
# > je suis desole si je vous ai effrayes .
# = i m sorry if i frightened you .
# < i m sorry i if i you am . <EOS>
#
# > elle sourit et prit conge .
# = she smiled and said goodbye .
# < she she him for the be work . <EOS>
#
# > tu n y es pas en securite .
# = you re not safe here .
# < you re not good yet . <EOS>
#
# > je ne vous donnerai aucun argent .
# = i m not giving you any money .
# < i m not not that that . <EOS>
#
# > je ne suis pas un locuteur natif .
# = i m not a native speaker .
# < i m not a good . <EOS>
#
# Iter: 6
# Learning Rate: 1
# Time: 0h 1m 30s
# Train Loss: 1.342745653663217
#
# > je suis encore endormie .
# = i m still sleepy .
# < i m not sure . <EOS>
#
# > elles sont autosuffisantes .
# = they re self sufficient .
# < they re in the same . <EOS>
#
# > elle est capable de tout .
# = she is capable of anything .
# < she is sure of is all . <EOS>
#
# > c est pour vous que je suis venu .
# = you re the reason i came .
# < you re the one i me . <EOS>
#
# > nous ne sommes pas en train d evacuer .
# = we re not evacuating .
# < we re not in . <EOS>
#
# > vous m intimidez toujours .
# = i m still intimidated by you .
# < i m so that that t that . <EOS>
#
# > on dit qu il est riche .
# = he is said to be rich .
# < he is likely to his his student . <EOS>
#
# > je suis ici pour t aider .
# = i m here to help you .
# < i m here to help you . <EOS>
#
# > elle va avoir un bebe .
# = she s going to have a baby .
# < she is a wearing . <EOS>
#
# > tu es un type genial .
# = you re a wonderful guy .
# < you re a liar person . <EOS>
#
# Iter: 7
# Learning Rate: 1
# Time: 0h 1m 45s
# Train Loss: 1.2450062272275955
#
# > ce n est pas un eleve ordinaire .
# = he is no ordinary student .
# < he is no a good man . <EOS>
#
# > c est une femme magnifique .
# = she is a wonderful wife .
# < she is a wonderful woman . <EOS>
#
# > tu es aussi grande que ma s ur .
# = you are as tall as my sister .
# < you re as as as my my car . <EOS>
#
# > desole de ce que j ai fait .
# = i am sorry for what i did .
# < i m sorry i have that i am . <EOS>
#
# > j en ai marre de vous .
# = i m sick of you .
# < i m sick of you . <EOS>
#
# > je n ai pas les foies .
# = i m not chicken .
# < i m not done . <EOS>
#
# > elle lui a envoye un message .
# = she sent him a message .
# < she him him a good student . <EOS>
#
# > mon poids me preoccupe .
# = i m worried about my weight .
# < i m so my father . <EOS>
#
# > il est a velo .
# = he is riding a bicycle .
# < he is a good student . <EOS>
#
# > vous allez etre pere .
# = you re going to be a father .
# < you re going to be a doctor . <EOS>
#
# Iter: 8
# Learning Rate: 1
# Time: 0h 2m 0s
# Train Loss: 1.1576578788154055
#
# > c est une etudiante qui etudie serieusement .
# = she is a student who studies very hard .
# < she s a very woman woman us . <EOS>
#
# > ils sont mes amis .
# = they re my friends .
# < they are my friends . <EOS>
#
# > t es un drole de gars .
# = you re a funny guy .
# < you are a liar person . <EOS>
#
# > je suis heureux de vous avoir invite .
# = i m glad i invited you .
# < i m glad i glad you . <EOS>
#
# > c est vous qui vous vous etes emballe .
# = you re the one that went crazy .
# < you re the one who you are are . <EOS>
#
# > il est une sorte de celebrite .
# = he is something of a celebrity .
# < he s a bit of a bit . <EOS>
#
# > tu es mince .
# = you re thin .
# < you are alone . <EOS>
#
# > tu triches .
# = you re cheating .
# < you are right . <EOS>
#
# > nous sommes serieuses .
# = we re serious .
# < we are tired . <EOS>
#
# > tu n aides pas tom .
# = you re not helping tom .
# < you aren t t tom . <EOS>
#
# Iter: 10
# Learning Rate: 1
# Time: 0h 2m 31s
# Train Loss: 1.0093070363771788
#
# > je suis un homme .
# = i am a man .
# < i m a man man . <EOS>
#
# > j ai la tete qui tourne .
# = i m feeling dizzy .
# < i m very interested in the teacher . <EOS>
#
# > je suis touchee !
# = i m hit !
# < i m proud . <EOS>
#
# > on est jamais trop vieux pour apprendre .
# = you re never too old to learn .
# < you re too old for this . <EOS>
#
# > j apprends tant de vous .
# = i m learning so much from you .
# < i m sorry for you . <EOS>
#
# > elles sont folles .
# = they re crazy .
# < they are busy . <EOS>
#
# > tu conduis trop vite .
# = you re driving too fast .
# < you re too young . <EOS>
#
# > nous nous parlons .
# = we re on speaking terms .
# < we re going to us . <EOS>
#
# > je n ai pas peur du tout .
# = i m not at all afraid .
# < i m not afraid of all . <EOS>
#
# > nous sommes faits l un pour l autre .
# = we re meant for each other .
# < we re just a only job . <EOS>
#
# Iter: 11
# Learning Rate: 1
# Time: 0h 2m 46s
# Train Loss: 0.9445695688590899
#
# > il est mechant .
# = he is nasty .
# < he s a man . <EOS>
#
# > vous etes fort avises .
# = you re very wise .
# < you re very upset . <EOS>
#
# > vous allez adorer nos plats .
# = you re going to love our food .
# < you re going to be making a lot of our time . <EOS>
#
# > je ne suis pas medecin mais enseignant .
# = i am not a doctor but a teacher .
# < i m not a doctor but a teacher . <EOS>
#
# > ce sont des employees a temps partiel .
# = they re part time employees .
# < they re both time . <EOS>
#
# > vous etes un merveilleux ami .
# = you re a wonderful friend .
# < you re a only friend friend . <EOS>
#
# > je suis desolee de vous avoir mal compris .
# = i m sorry i misunderstood you .
# < i m sorry i hurt you . <EOS>
#
# > c est un bon chanteur .
# = he is a good singer .
# < he is a good good person . <EOS>
#
# > tu analyses trop .
# = you re over analyzing .
# < you re too new . <EOS>
#
# > je suis un bon garcon .
# = i am a good boy .
# < i m a good good boy . <EOS>
#
# Iter: 12
# Learning Rate: 1
# Time: 0h 3m 1s
# Train Loss: 0.8846498652701685
#
# > je suis en retard .
# = i m behind schedule .
# < i m late . <EOS>
#
# > je ne suis pas une sainte .
# = i m no saint .
# < i m not a doctor . <EOS>
#
# > il n est pas du tout satisfait .
# = he isn t happy at all .
# < he is not at all all . <EOS>
#
# > je suis juste un type normal .
# = i m just a normal guy .
# < i m just a little guy . <EOS>
#
# > il est maladroit de ses mains .
# = he is clumsy with his hands .
# < he is by his fond of his parents . <EOS>
#
# > elle parle trop .
# = she speaks too much .
# < she s very new too . <EOS>
#
# > vous etes tres avisee .
# = you re very wise .
# < you re very funny . <EOS>
#
# > il se plaint toujours de quelque chose .
# = he s always complaining about something .
# < he s always complaining of our cute . <EOS>
#
# > ma journee est tres dure aujourd hui .
# = i m having a very difficult time today .
# < you are a very hard today . <EOS>
#
# > je suis remplacable .
# = i m replaceable .
# < i m not impressed . <EOS>
#
# Iter: 13
# Learning Rate: 1
# Time: 0h 3m 16s
# Train Loss: 0.8343898565329237
#
# > je n ai absolument pas peur .
# = i m not afraid at all .
# < i m not afraid i don t afraid . <EOS>
#
# > je ne suis pas bon a ca .
# = i m not good at this .
# < i m not good at this . <EOS>
#
# > tu es l elu .
# = you are the chosen one .
# < you re the one one one . <EOS>
#
# > je suis la pour te proteger .
# = i m here to protect you .
# < i m here to protect you . <EOS>
#
# > je suis folle .
# = i m crazy .
# < i m crazy . <EOS>
#
# > il parle vite .
# = he is a fast speaker .
# < he s a bad doctor but he a doctor . <EOS>
#
# > je suis bien conscient de ca .
# = i m well aware of that .
# < i m sure of that this . <EOS>
#
# > tu n es pas aussi petit que moi .
# = you aren t as short as i am .
# < you aren t as smart as me . <EOS>
#
# > c est un beau mec .
# = he s a hunk .
# < he is a kind of kind . <EOS>
#
# > vous etes suffisante .
# = you re conceited .
# < you are kind of mine . <EOS>
#
# Iter: 14
# Learning Rate: 1
# Time: 0h 3m 32s
# Train Loss: 0.7851085189950936
#
# > nous sommes toutes armees .
# = we re all armed .
# < we re all all together . <EOS>
#
# > vous etes incroyable .
# = you re incredible .
# < you re a wonderful wreck . <EOS>
#
# > tu es difficile .
# = you re fussy .
# < you re in luck . <EOS>
#
# > c est moi qui suis si malade .
# = i am so sick .
# < i m so so angry . <EOS>
#
# > tu es l ami de tom pas vrai ?
# = you re tom s friend aren t you ?
# < you re one of tom s friend ? <EOS>
#
# > il est un peu reveche .
# = he s a bit rough around the edges .
# < he s a bit man . <EOS>
#
# > je n en ai pas fini avec toi .
# = i m not done with you .
# < i m not done with you . <EOS>
#
# > elle m est etrangere .
# = she is a stranger to me .
# < she s the teacher me . <EOS>
#
# > je m y habitue .
# = i m getting used to it .
# < i m used to go to go . <EOS>
#
# > vous etes tres marrant .
# = you re very funny .
# < you re very very funny . <EOS>
#
# Iter: 15
# Learning Rate: 1
# Time: 0h 3m 47s
# Train Loss: 0.7367841065105787
#
# > je songe a y aller .
# = i m thinking of going .
# < i m used to go . <EOS>
#
# > il est tres prudent .
# = he is being very careful .
# < he is very kind of all . <EOS>
#
# > je suis sur que vous allez reussir .
# = i m sure that you ll succeed .
# < i m sure you ll ll it . <EOS>
#
# > tu te fais comprendre .
# = you re assertive .
# < you re going to you this tree . <EOS>
#
# > t es un sacre coco .
# = you re a jolly good feller .
# < you are a good good now . <EOS>
#
# > votre decollage est confirme .
# = you are cleared for takeoff .
# < you re your way . <EOS>
#
# > je viens d amerique .
# = i m from america .
# < i m from from him . <EOS>
#
# > je suis encore ici .
# = i m still here .
# < i m still here . <EOS>
#
# > ils sont disposes a discuter du probleme .
# = they are willing to talk about the problem .
# < they are the ones to the lot . <EOS>
#
# > je cherche du travail .
# = i m looking for work .
# < i am looking for her work . <EOS>
#
# Iter: 16
# Learning Rate: 1
# Time: 0h 4m 2s
# Train Loss: 0.694354615919475
#
# > je n ai pas termine .
# = i m not done .
# < i m not done . <EOS>
#
# > il a l habitude de travailler dur .
# = he is accustomed to working hard .
# < he is used to work at work . <EOS>
#
# > je suis aussi age que vous .
# = i m as old as you .
# < i m as curious as you as are . <EOS>
#
# > il se planque .
# = he s gone into hiding .
# < he s gone out of hiding . <EOS>
#
# > nous sommes plutot occupes ici .
# = we re kind of busy here .
# < we re kind of busy busy here . <EOS>
#
# > tu es mon type .
# = you re my type .
# < you re my kid person . <EOS>
#
# > vous etes des cretins .
# = you are morons .
# < you are one of the wrong team . <EOS>
#
# > je suis plus petit que vous .
# = i m shorter than you .
# < i m more than you . <EOS>
#
# > on va essayer encore une fois .
# = we re going to give it another try .
# < we re going to be going to be a team . <EOS>
#
# > nous avons termine .
# = we re done .
# < we re all done . <EOS>
#
# Iter: 17
# Learning Rate: 1
# Time: 0h 4m 18s
# Train Loss: 0.6508829305305599
#
# > je suis actuellement au telephone avec tom .
# = i m on the phone with tom now .
# < i am on the way to tom . <EOS>
#
# > vous etes si belle dans cette robe !
# = you re so beautiful in that dress .
# < you re so beautiful in that dress . <EOS>
#
# > je suis occupe .
# = i m busy .
# < i m busy . <EOS>
#
# > nous sommes des adultes .
# = we re adults .
# < we re unambitious . <EOS>
#
# > il est ton fils .
# = he s your son .
# < he s your son . <EOS>
#
# > je suis ton frere .
# = i m your brother .
# < i m your brother . <EOS>
#
# > je ne lui suis pas lie .
# = i am not acquainted with him .
# < i m not offended with it . <EOS>
#
# > je n y suis pas tres bon .
# = i m not very good at it .
# < i m not very good at it . <EOS>
#
# > je viens de russie .
# = i am from russia .
# < i am from reading . <EOS>
#
# > je crains que vous vous egariez .
# = i am afraid that you will get lost .
# < i m afraid you will get wrong . <EOS>
#
# Iter: 18
# Learning Rate: 1
# Time: 0h 4m 33s
# Train Loss: 0.6138996969321175
#
# > je suis allergique aux chiens .
# = i m allergic to dogs .
# < i m allergic to your health . <EOS>
#
# > vous etes tres genereux .
# = you re very generous .
# < you re very wise . <EOS>
#
# > vous etes belle .
# = you are beautiful .
# < you are beautiful . <EOS>
#
# > il est employe de banque .
# = he is a bank clerk .
# < he is a expert now . <EOS>
#
# > il est experimente dans l evaluation d antiquites .
# = he is experienced in valuing antiques .
# < he is sitting in the college . <EOS>
#
# > je suis aveugle .
# = i m blind .
# < i m certain . <EOS>
#
# > je ne sors pas .
# = i m not going outside .
# < i m not going to understand . <EOS>
#
# > vous etes maigrichonne .
# = you re skinny .
# < you re early . <EOS>
#
# > nous sommes riches .
# = we re rich .
# < we are good now . <EOS>
#
# > tu es trop bruyant .
# = you re too loud .
# < you re too too man . <EOS>
#
# Iter: 19
# Learning Rate: 1
# Time: 0h 4m 49s
# Train Loss: 0.5769630927759792
#
# > je suis pret .
# = i m prepared .
# < i m ready . <EOS>
#
# > je suis sur d avoir ferme le gaz .
# = i m sure i turned off the gas .
# < i am sure i have off the gas . <EOS>
#
# > ils sont contents du resultat .
# = they are happy with the result .
# < they re about the result . <EOS>
#
# > je suis ta s ur .
# = i m your sister .
# < i m your sister . <EOS>
#
# > je suis allergique aux chats .
# = i m allergic to cats .
# < i m allergic to cats . <EOS>
#
# > vous etes mignonne dans votre genre .
# = you re kind of cute .
# < you re kind of cute . <EOS>
#
# > tu es talentueux .
# = you re talented .
# < you re very talented . <EOS>
#
# > je n ai pas peur du tout .
# = i m not at all afraid .
# < i m not at all at all . <EOS>
#
# > je suis tellement fier de vous .
# = i m so proud of you .
# < i m so proud of you . <EOS>
#
# > vous n etes plus mon ami .
# = you re not my friend anymore .
# < you re not my friend anymore . <EOS>
#
# Iter: 20
# Learning Rate: 1
# Time: 0h 5m 4s
# Train Loss: 0.5439357884396726
#
# > il se plaint toujours de la nourriture .
# = he s always complaining about the food .
# < he s always complaining about the result . <EOS>
#
# > je ne suis pas de garde demain .
# = i am off duty tomorrow .
# < i m out of duty . <EOS>
#
# > nous nous faisons des idees .
# = we re imagining things .
# < we re doing having things . <EOS>
#
# > c est un homme cultive .
# = he is a learned man .
# < he is a man man . <EOS>
#
# > je suis prete a te suivre .
# = i am ready to follow you .
# < i am ready to follow you . <EOS>
#
# > tu es matinale .
# = you are early .
# < you re in the way . <EOS>
#
# > tu es idiot .
# = you re silly .
# < you re a nervous guy . <EOS>
#
# > je ne suis pas tres organise .
# = i m not very organized .
# < i m not very good at t . <EOS>
#
# > je vais rentrer chez moi demain .
# = i m going back home tomorrow .
# < i m going to go home this tomorrow . <EOS>
#
# > je m en occupe .
# = i m taking care of it .
# < i m getting up . <EOS>
#
# Iter: 21
# Learning Rate: 1
# Time: 0h 5m 19s
# Train Loss: 0.5117519906879215
#
# > ils sont probablement etasuniens .
# = they re probably americans .
# < they are probably probably a bad guy . <EOS>
#
# > je ne vais plus le faire .
# = i m not doing it anymore .
# < i m not doing any any anymore . <EOS>
#
# > elles sont toutes normales .
# = they re all normal .
# < they re all dead . <EOS>
#
# > j en ai peur .
# = i m afraid so .
# < i m sick of all . <EOS>
#
# > je suis a votre merci .
# = i m at your mercy .
# < i m at your opinion . <EOS>
#
# > je suis finlandais .
# = i m finnish .
# < i m a beginner . <EOS>
#
# > je vais preparer a diner .
# = i m going to fix some dinner .
# < i m going to fix some dinner . <EOS>
#
# > je cherche le gerant .
# = i m looking for the manager .
# < i m looking for the job . <EOS>
#
# > je ne vais pas disparaitre .
# = i m not going to disappear .
# < i m not going to get good . <EOS>
#
# > je ne suis pas amer .
# = i m not bitter .
# < i m not that impressed . <EOS>
#
# Iter: 22
# Learning Rate: 1
# Time: 0h 5m 35s
# Train Loss: 0.48043130955825825
#
# > ta chance est epuisee .
# = you re out of luck .
# < you re out of all . <EOS>
#
# > je suis maigrichonne .
# = i m skinny .
# < i m retired . <EOS>
#
# > vous etes fort elegantes .
# = you re very stylish .
# < you re very timid . <EOS>
#
# > tu es une opportuniste .
# = you re opportunistic .
# < you re a traitor . <EOS>
#
# > il est encore fache .
# = he is still angry .
# < he s still young . <EOS>
#
# > vous n etes pas morts .
# = you re not dead .
# < you aren t dead . <EOS>
#
# > vous arrivez trop tard .
# = you are too late .
# < you re too late . <EOS>
#
# > je suis sobre .
# = i m sober .
# < i m retired . <EOS>
#
# > elle est mon amie .
# = she s my friend .
# < she is my friend friend . <EOS>
#
# > je suis a toi .
# = i m yours .
# < i m yours . <EOS>
#
# Iter: 23
# Learning Rate: 1
# Time: 0h 5m 50s
# Train Loss: 0.4529807154134387
#
# > vous n etes pas medecin .
# = you re not a doctor .
# < you re not a doctor . <EOS>
#
# > je suis ton frere .
# = i m your brother .
# < i m your brother . <EOS>
#
# > je ne le gobe toujours pas .
# = i m still not buying it .
# < i m still not doing it . <EOS>
#
# > vous etes trop jeunes pour voyager seules .
# = you are too young to travel alone .
# < you are too young to travel alone . <EOS>
#
# > nous sommes confrontes a un tas de problemes .
# = we are faced with a host of problems .
# < we are faced with a host of problems . <EOS>
#
# > je ne suis pas la patronne .
# = i m not the boss .
# < i m not the boss . <EOS>
#
# > elles sont toutes parties .
# = they re all gone .
# < they re all all dead . <EOS>
#
# > vous etes cernees .
# = you re surrounded .
# < you re a lazy wreck . <EOS>
#
# > il est votre ami .
# = he s your friend .
# < he s your friend . <EOS>
#
# > vous etes surmenees .
# = you re overworked .
# < you re clever . <EOS>
#
# Iter: 24
# Learning Rate: 1
# Time: 0h 6m 6s
# Train Loss: 0.4242069517108738
#
# > je vais bientot etre partie .
# = i m going to be gone soon .
# < i m going to be working right now . <EOS>
#
# > je suis mariee .
# = i am married .
# < i m married . <EOS>
#
# > ils sont sortis faire les magasins .
# = they are out shopping .
# < they are out shopping . <EOS>
#
# > elle est aussi jolie que sa s ur .
# = she s as pretty as her sister .
# < she is as tall as her sister . <EOS>
#
# > vous etes fort emotive .
# = you re very emotional .
# < you are very emotional . <EOS>
#
# > il est intelligent .
# = he s intelligent .
# < he is intelligent . <EOS>
#
# > il est si jeune .
# = he s so young .
# < he s so young . <EOS>
#
# > nous allons bien tous les deux .
# = we re both fine .
# < we re going to travel both both . <EOS>
#
# > elle a les pieds en dedans .
# = she is pigeon toed .
# < she is got flowers . <EOS>
#
# > il est impopulaire pour une raison quelconque .
# = he is unpopular for some reason .
# < he is good for a job . <EOS>
#
# Iter: 25
# Learning Rate: 1
# Time: 0h 6m 21s
# Train Loss: 0.39824919999524905
#
# > ils vous attendent .
# = they re waiting for you .
# < they re waiting for you . <EOS>
#
# > je suis toubib .
# = i m a doctor .
# < i m a doctor . <EOS>
#
# > je suis finlandais .
# = i m finnish .
# < i m full . <EOS>
#
# > je suis ravi d etre ici .
# = i am delighted to be here .
# < i m delighted to be here . <EOS>
#
# > nous travaillons a l instant .
# = we re working at the moment .
# < we re working at the moment . <EOS>
#
# > il est grand et fort .
# = he is tall and strong .
# < he is tall and very man . <EOS>
#
# > tu es un menteur .
# = you re a liar .
# < you re a liar . <EOS>
#
# > nous allons fouiller la totalite du bateau .
# = we re going to search the whole ship .
# < we re going to have the problem ship . <EOS>
#
# > vous etes un sacre coco .
# = you re a jolly good feller .
# < you re a jolly good person . <EOS>
#
# > elle a de si beaux yeux .
# = she s got such lovely eyes .
# < she s got such such a bad room . <EOS>
#
# Iter: 26
# Learning Rate: 1
# Time: 0h 6m 36s
# Train Loss: 0.374567106988382
#
# > elle est plus grande que sa s ur .
# = she is taller than her sister .
# < she is taller than her sister . <EOS>
#
# > je ne me dispute pas .
# = i m not arguing .
# < i m not getting involved . <EOS>
#
# > je t observe .
# = i m watching you .
# < i m looking you . <EOS>
#
# > nous derangeons .
# = we re interfering .
# < re all having a blast . <EOS>
#
# > nous jouons au tennis ce week end .
# = we are playing tennis this weekend .
# < we are playing tennis this game . <EOS>
#
# > je suis heureux qu il l ait apprecie .
# = i m glad he liked it .
# < i m glad he liked it . <EOS>
#
# > elles forment le dessus du panier .
# = they re the cream of the crop .
# < they re the cream of the crop . <EOS>
#
# > il est trop ivre .
# = he s too drunk .
# < he s too drunk . <EOS>
#
# > je ne suis pas seul .
# = i m not alone .
# < i m not alone . <EOS>
#
# > vous imaginez des choses .
# = you re imagining things .
# < you re making things . <EOS>
#
# Iter: 27
# Learning Rate: 1
# Time: 0h 6m 52s
# Train Loss: 0.3528509294408459
#
# > nous sommes desoles pour l interruption .
# = we are sorry for the interruption .
# < we are sorry for the interruption . <EOS>
#
# > vous etes trop jeune pour voyager seule .
# = you are too young to travel alone .
# < you are too young to travel alone . <EOS>
#
# > nous allons essayer .
# = we re going to try .
# < we re going to have it . <EOS>
#
# > il est mieux que quiconque .
# = he is better than anyone else .
# < he s better than ever anyone . <EOS>
#
# > tu es endormie .
# = you re sleepy .
# < you re sleepy . <EOS>
#
# > je suis content que nous ayons vu tom .
# = i m glad we saw tom .
# < i m glad we can tom . <EOS>
#
# > tu es un sacre menteur .
# = you re such a liar .
# < you re such a liar . <EOS>
#
# > vous etes plus grands que moi .
# = you re taller than i am .
# < you re taller than me . <EOS>
#
# > je ne suis pas disponible .
# = i m not available .
# < i m not available . <EOS>
#
# > vous etes tres perspicaces .
# = you re very perceptive .
# < you re very generous . <EOS>
#
# Iter: 28
# Learning Rate: 1
# Time: 0h 7m 7s
# Train Loss: 0.32882502896791205
#
# > je suis en avance .
# = i m early .
# < i m early . <EOS>
#
# > il n est pas du tout satisfait .
# = he isn t happy at all .
# < he isn t happy at all . <EOS>
#
# > je suis meilleur que lui .
# = i m better than him .
# < i m better than him . <EOS>
#
# > nous sommes frere et s ur .
# = we are brother and sister .
# < we are sorry and sister . <EOS>
#
# > ce sont ceux qui veulent s y rendre .
# = they are the ones who want to go .
# < they are the ones who want to go . <EOS>
#
# > il est loin de chez lui .
# = he is away from home .
# < he is on far at home . <EOS>
#
# > nous nous rendons au cinema .
# = we re going to the movies .
# < we re going to the movies . <EOS>
#
# > je suis toujours occupe .
# = i m busy all the time .
# < i m busy all the same . <EOS>
#
# > je travaille sur sa voiture .
# = i m working on his car .
# < i m working on his car car . <EOS>
#
# > je suis desolee je ne parle pas francais .
# = i m sorry i don t speak french .
# < i m sorry i don t speak french . <EOS>
#
# Iter: 29
# Learning Rate: 1
# Time: 0h 7m 23s
# Train Loss: 0.30873376477042064
#
# > j attends une lettre d elle .
# = i m expecting a letter from her .
# < i m expecting a lot of her trip . <EOS>
#
# > je vais a cet endroit .
# = i am going to that place .
# < i m going to do this right . <EOS>
#
# > vous etes consciencieux .
# = you re conscientious .
# < you re totally gorgeous . <EOS>
#
# > on est fauches .
# = we re broke .
# < we re broke . <EOS>
#
# > il s inquiete de sa calvitie naissante .
# = he s worried about his receding hairline .
# < he s worried about his new result . <EOS>
#
# > elles sont fatiguees .
# = they re tired .
# < they re tired . <EOS>
#
# > je viens du bresil .
# = i am from brazil .
# < i am from brazil . <EOS>
#
# > tu chantes tout le temps .
# = you re always singing .
# < you re always investigation . <EOS>
#
# > vous etes imprudents .
# = you re foolish .
# < you are a big . <EOS>
#
# > nous avons toutes peur .
# = we re all scared .
# < we re all scared of all . <EOS>
#
# Iter: 30
# Learning Rate: 1
# Time: 0h 7m 38s
# Train Loss: 0.29035363521625934
#
# > je suis si malade .
# = i am so sick .
# < i am so sick . <EOS>
#
# > cela m intrigue .
# = i m intrigued .
# < i m bored to me . <EOS>
#
# > tu es tres gentil .
# = you re very nice .
# < you re very nice kind . <EOS>
#
# > elles sont eveillees .
# = they re awake .
# < they are awake . <EOS>
#
# > je suis en train d utiliser l ordinateur .
# = i m using the computer .
# < i m using the computer . <EOS>
#
# > nous sommes vraiment en colere .
# = we re really angry .
# < we re really angry . <EOS>
#
# > vous etes des idiots .
# = you are morons .
# < you are one of the choir . <EOS>
#
# > j attends toujours pour ma commande .
# = i m still waiting for my order .
# < i m still waiting for my loss of my loss . <EOS>
#
# > je ne prends pas non pour une reponse .
# = i m not taking no for an answer .
# < i m not taking no for an answer . <EOS>
#
# > elle parlait bien le japonais .
# = she spoke japanese well .
# < she studies well well . <EOS>
#
# Iter: 31
# Learning Rate: 1
# Time: 0h 7m 54s
# Train Loss: 0.2707357037432737
#
# > je ne suis plus un enfant .
# = i am no longer a child .
# < i m not a child anymore . <EOS>
#
# > il s ameliore petit a petit .
# = he is getting better bit by bit .
# < he is getting getting bit bit with a bit . <EOS>
#
# > vous ne saignez pas .
# = you re not bleeding .
# < you re not fit . <EOS>
#
# > j ai environ le meme age que toi .
# = i m about the same age as you .
# < i m about the same age as you . <EOS>
#
# > je ne suis pas endormi .
# = i m not asleep .
# < i m not sleepy . <EOS>
#
# > elle parle anglais avec un accent etranger .
# = she speaks english with a foreign accent .
# < she english with a foreign foreign foreign . <EOS>
#
# > elles sont russes .
# = they are russian .
# < they are a busy . <EOS>
#
# > j en ai marre de lui .
# = i m fed up with him .
# < i m tired of him . <EOS>
#
# > je suis enchante de te rencontrer .
# = i m delighted to meet you .
# < i m delighted to meet you . <EOS>
#
# > c est un fumeur invetere .
# = he s a chain smoker .
# < he s a typical fellow . <EOS>
#
# Iter: 32
# Learning Rate: 1
# Time: 0h 8m 9s
# Train Loss: 0.2529719907352082
#
# > j en ai assez de ma vie monotone .
# = i am tired of my monotonous life .
# < i am tired of my life life . <EOS>
#
# > je suis voyant .
# = i m psychic .
# < i m retired . <EOS>
#
# > elles sont en train de te chercher .
# = they re looking for you .
# < they re looking for you . <EOS>
#
# > ils sont libres .
# = they re free .
# < they all tired . <EOS>
#
# > elle voyage autour du monde .
# = she is traveling around the world .
# < she smiled the world world . <EOS>
#
# > je suis desolee de vous avoir derange .
# = i m sorry to have disturbed you .
# < i m sorry to have disturbed you . <EOS>
#
# > je commence a sentir que quelque chose deconne .
# = i m beginning to smell a rat .
# < i m beginning to give a rat . <EOS>
#
# > elle etudie ardemment .
# = she studies hard .
# < she studies in speaking other . <EOS>
#
# > je suis aussi agee que toi .
# = i m as old as you .
# < i m as old as you are . <EOS>
#
# > vous etes givres !
# = you re nuts !
# < you re so sweet . <EOS>
#
# Iter: 33
# Learning Rate: 1
# Time: 0h 8m 25s
# Train Loss: 0.23795738769570007
#
# > ils sont si droles .
# = they re so funny .
# < they re so funny . <EOS>
#
# > elles sont toutes en vacances .
# = they re all on vacation .
# < they re all on vacation . <EOS>
#
# > je suis en colere apres toi .
# = i m mad at you .
# < i m mad at you . <EOS>
#
# > vous plaisantez !
# = you re joking !
# < you re kidding . <EOS>
#
# > nous sommes tres excites .
# = we re very excited .
# < we re very excited . <EOS>
#
# > je suis seule .
# = i m alone .
# < i m alone . <EOS>
#
# > il est toujours debout .
# = he is still standing .
# < he is always alive . <EOS>
#
# > vous etes le professeur de mon enfant .
# = you re my kid s teacher .
# < you re my kid s teacher . <EOS>
#
# > je me trouve juste derriere lui .
# = i m right behind him .
# < i m right behind him . <EOS>
#
# > elle est mannequin .
# = she s a model .
# < she s a model . <EOS>
#
# Iter: 34
# Learning Rate: 1
# Time: 0h 8m 40s
# Train Loss: 0.2215379891533103
#
# > je suis heureux de vous avoir rencontre .
# = i m very happy to make your acquaintance .
# < i m very glad i hired you . <EOS>
#
# > elle achete toujours du lait .
# = she still buys milk .
# < she still always complaining . <EOS>
#
# > ils sont en train de nettoyer la plage .
# = they re cleaning the beach .
# < they re there the beach . <EOS>
#
# > il est en danger grave .
# = he s in grave danger .
# < he s in danger . <EOS>
#
# > je suis inquiet pour sa sante .
# = i am anxious about his health .
# < i am worried about his health . <EOS>
#
# > je suis tres grand .
# = i am very tall .
# < i am very tall . <EOS>
#
# > je ne suis pas une enfant .
# = i m not a child .
# < i m not a child . <EOS>
#
# > je suis vraiment embarrassee .
# = i m really embarrassed .
# < i m really a normal . <EOS>
#
# > vous etes tres comprehensives .
# = you re very understanding .
# < you re very observant . <EOS>
#
# > tu es tres curieux .
# = you re very curious .
# < you re very curious . <EOS>
#
# Iter: 35
# Learning Rate: 1
# Time: 0h 8m 55s
# Train Loss: 0.20676277490355321
#
# > vous etes une etudiante .
# = you are a student .
# < you a a student . <EOS>
#
# > nous allons beaucoup nous amuser .
# = we re going to have so much fun .
# < we re going to have so much together . <EOS>
#
# > tu es bon cuisinier non ?
# = you are a good cook aren t you ?
# < you are good cook aren t you ? <EOS>
#
# > elle a peur des chiens .
# = she s scared of dogs .
# < she s afraid of dogs . <EOS>
#
# > j ai quelques difficultes a compiler ce programme .
# = i m having some problems compiling this software .
# < i m having some problems problems this wet . <EOS>
#
# > je fais preuve de bon sens .
# = i m being sensible .
# < i m in a good mood . <EOS>
#
# > elle cria a l aide .
# = she screamed for help .
# < she screamed for help . <EOS>
#
# > il n est pas vraiment l impresario .
# = he isn t actually the manager .
# < he isn t actually the manager . <EOS>
#
# > je suis en train de regarder la television .
# = i m watching tv .
# < i m watching tv . <EOS>
#
# > je compte m acheter une nouvelle voiture .
# = i m going to buy a new car .
# < i m going to buy a new car . <EOS>
#
# Iter: 36
# Learning Rate: 1
# Time: 0h 9m 11s
# Train Loss: 0.19350945373532502
#
# > il n est bon a rien .
# = he is good for nothing .
# < he is good for nothing . <EOS>
#
# > t es bourre .
# = you re loaded .
# < you re loaded . <EOS>
#
# > c est un tres bon musicien .
# = he s a very fine musician .
# < he s a very fine musician . <EOS>
#
# > je pars en vacances pour quelques jours .
# = i m taking a couple of days off .
# < i m taking a couple of days off . <EOS>
#
# > il agit en son nom propre .
# = he is acting on his own behalf .
# < he s acting on his own grave . <EOS>
#
# > nous ne sommes pas les bienvenus .
# = we re not welcome .
# < we re not welcome . <EOS>
#
# > je vais vous donner une lecon .
# = i m going to teach you a lesson .
# < i m going to teach you a lesson . <EOS>
#
# > je ne suis pas encore fatigue .
# = i m not tired yet .
# < i m not tired yet . <EOS>
#
# > elle est sure de reussir .
# = she s sure to succeed .
# < she s sure of succeed . <EOS>
#
# > tu es depourvue d ambition .
# = you re unambitious .
# < you re unambitious . <EOS>
#
# Iter: 37
# Learning Rate: 1
# Time: 0h 9m 26s
# Train Loss: 0.18038281918705115
#
# > je suis affame !
# = i m famished .
# < i m so ! <EOS>
#
# > je suis desolee de vous avoir deranges !
# = i m sorry to have bothered you .
# < i m sorry to have bothered you . <EOS>
#
# > je suis folle .
# = i m crazy .
# < i am crazy . <EOS>
#
# > je ne suis pas particulierement impressionnee .
# = i m not particularly impressed .
# < i m not impressed impressed . <EOS>
#
# > avec plaisir .
# = you re welcome .
# < you re in the problem . <EOS>
#
# > tu es probablement trop jeune pour le comprendre .
# = you re probably too young to understand this .
# < you re probably too young to understand this . <EOS>
#
# > vous etes plus grand que moi .
# = you re taller than i am .
# < you re taller than me . <EOS>
#
# > elle est sous la chaise .
# = she s under the chair .
# < she s under the chair . <EOS>
#
# > je ne vais pas signer ceci .
# = i m not going to sign this .
# < i m not going to play this . <EOS>
#
# > je n en ai pas fini avec toi .
# = i m not finished with you .
# < i m not finished with you . <EOS>
#
# Iter: 38
# Learning Rate: 1
# Time: 0h 9m 42s
# Train Loss: 0.16863805960237455
#
# > je suis tout ouie .
# = i m all ears .
# < i am all ears . <EOS>
#
# > c est maree basse .
# = you re out of booze .
# < you re out to know . <EOS>
#
# > elle vit au milieu de nulle part .
# = she is living in the middle of nowhere .
# < she is living in the middle of nowhere . <EOS>
#
# > elles sont tres grandes .
# = they are very big .
# < they are very big . <EOS>
#
# > j ai les crocs .
# = i m starved .
# < i m hungry . <EOS>
#
# > vous etes vilaine .
# = you are naughty .
# < you are a teacher . <EOS>
#
# > nous regrettons de ne pas pouvoir vous aider .
# = we are sorry we can t help you .
# < we re sorry we can t help you . <EOS>
#
# > tu es riche n est ce pas ?
# = you re wealthy aren t you ?
# < you re wealthy aren t you ? <EOS>
#
# > nous appartenons tous a la meme equipe .
# = we re all on the same team .
# < we re all on the same team . <EOS>
#
# > nous travaillons toutes dur .
# = we re all working hard .
# < we re all working hard . <EOS>
#
# Iter: 39
# Learning Rate: 1
# Time: 0h 9m 57s
# Train Loss: 0.15801972209996995
#
# > nous ne sommes pas maries .
# = we re not married .
# < we re not married . <EOS>
#
# > j appelle la securite .
# = i m calling security .
# < i m calling here . <EOS>
#
# > tu es tres bon .
# = you re very good .
# < you re very good now . <EOS>
#
# > je suis tres fier de mon pere .
# = i m very proud of my father .
# < i m very proud of my father . <EOS>
#
# > il est bon .
# = he s good .
# < he s good at good . <EOS>
#
# > elle s assit pres de moi .
# = she sat next to me .
# < she sat next to me . <EOS>
#
# > tu es dans la merde .
# = you re in big trouble .
# < you re in trouble . <EOS>
#
# > je ne suis pas assure .
# = i m uninsured .
# < i m not interested . <EOS>
#
# > tu vas adorer notre nourriture .
# = you re going to love our food .
# < you re going to love our food . <EOS>
#
# > je vais vous donner une lecon .
# = i m going to teach you a lesson .
# < i m going to teach you a lesson . <EOS>
#
# Iter: 40
# Learning Rate: 1
# Time: 0h 10m 13s
# Train Loss: 0.14820907063872577
#
# > je suis etudiant a l universite .
# = i m a university student .
# < i am a university student . <EOS>
#
# > j ai sommeil alors je pars maintenant .
# = i m sleepy so i am leaving now .
# < i m sleepy i m sleepy now . <EOS>
#
# > vous etes tous hypocrites .
# = you re all hypocritical .
# < you re all that mood . <EOS>
#
# > je joue avec mes amies .
# = i m playing with my friends .
# < i m playing with my friends . <EOS>
#
# > je vais ecrire une lettre demain .
# = i am going to write a letter tomorrow .
# < i am going to write a letter tomorrow . <EOS>
#
# > vous etes puissants .
# = you re powerful .
# < you re too slow . <EOS>
#
# > tu es tellement previsible !
# = you re so predictable .
# < you re so picky . <EOS>
#
# > elle a peur des chats .
# = she is afraid of cats .
# < she is afraid of cats . <EOS>
#
# > c est un interprete dans une banque internationale .
# = he s an interpreter in an international bank .
# < he s an interpreter in an international bank . <EOS>
#
# > vous etes responsable .
# = you are to blame .
# < you are responsible for the do . <EOS>
#
# Iter: 41
# Learning Rate: 1
# Time: 0h 10m 28s
# Train Loss: 0.1370583216134387
#
# > je suis content d etre la .
# = i m glad to be here .
# < i m glad to be here . <EOS>
#
# > elle parle difficilement un mot d anglais .
# = she spoke scarcely a word of english .
# < she spoke scarcely a word of english . <EOS>
#
# > je vais etre papa .
# = i m going to be a father .
# < i m going to be a father . <EOS>
#
# > je suis contente que vous soyez en avance .
# = i m glad you re early .
# < i m glad you re early . <EOS>
#
# > nous faisons du benevolat .
# = we re volunteering .
# < we re volunteering . <EOS>
#
# > je ne suis pas medecin mais instituteur .
# = i m not a doctor but a teacher .
# < i am not a doctor but a teacher . <EOS>
#
# > c est vraiment un bon travailleur .
# = he is a really good worker .
# < he is a really good worker . <EOS>
#
# > c est de notre faute a tous .
# = we re all to blame for that .
# < we re all to blame to that . <EOS>
#
# > vous etes toutes contentes .
# = you re all happy .
# < you re all happy . <EOS>
#
# > tu n es pas toi meme aujourd hui .
# = you re not yourself today .
# < you re not yourself today . <EOS>
#
# Iter: 42
# Learning Rate: 1
# Time: 0h 10m 43s
# Train Loss: 0.12906851021335466
#
# > je suis habitue a travailler dur .
# = i am accustomed to working hard .
# < i am accustomed to working hard . <EOS>
#
# > tu preches une convaincue .
# = you re preaching to the choir .
# < you re preaching to the choir . <EOS>
#
# > vous avez probablement raison .
# = you re probably right .
# < you are probably that . <EOS>
#
# > je suis desolee si je vous ai effrayes .
# = i m sorry if i frightened you .
# < i m sorry if i frightened you . <EOS>
#
# > je suis sur que vos pensees sont nobles .
# = i am certain that you have noble thoughts .
# < i am certain that you have noble thoughts . <EOS>
#
# > vous etes libre d y aller .
# = you re free to go .
# < you re free to go . <EOS>
#
# > je me porte bien .
# = i m okay .
# < i m feeling good . <EOS>
#
# > nous ne sommes pas des barbares .
# = we re not barbarians .
# < we re not barbarians . <EOS>
#
# > vous etes l institutrice de mon enfant .
# = you re my kid s teacher .
# < you re my kid s teacher . <EOS>
#
# > je suis un citoyen francais .
# = i m a french citizen .
# < i m a french citizen . <EOS>
#
# Iter: 43
# Learning Rate: 1
# Time: 0h 10m 59s
# Train Loss: 0.12045018530524935
#
# > elles sont toutes contre moi .
# = they re all against me .
# < they re all against me . <EOS>
#
# > j essaie de dormir .
# = i m trying to sleep .
# < i m trying to sleep . <EOS>
#
# > elles ne constituent pas une menace .
# = they re not a threat .
# < they re not a threat . <EOS>
#
# > elle est deux ans plus vieille que toi .
# = she is two years older than you .
# < she is two years older than you . <EOS>
#
# > je suis depourvu de talent .
# = i m untalented .
# < i m between out of breath . <EOS>
#
# > il est desesperement amoureux .
# = he s hopelessly in love .
# < he s hopelessly in love . <EOS>
#
# > on peut compter sur elle .
# = she is a reliable person .
# < she is a reliable person . <EOS>
#
# > je vous licencie .
# = i m laying you off .
# < i m laying you off . <EOS>
#
# > tu preches des convaincues .
# = you re preaching to the choir .
# < you re preaching to the choir . <EOS>
#
# > je suis aussi choque que toi .
# = i m as shocked as you are .
# < i m as shocked as you are . <EOS>
#
# Iter: 44
# Learning Rate: 1
# Time: 0h 11m 14s
# Train Loss: 0.11302190809728904
#
# > vous n interrompez rien .
# = you re not interrupting anything .
# < you re not interrupting anything . <EOS>
#
# > vous etes celle la .
# = you are the one .
# < you re the one now . <EOS>
#
# > nous y sommes actuellement .
# = we re here now .
# < we re here now . <EOS>
#
# > tu es le champion n est ce pas ?
# = you re the champion aren t you ?
# < you re the champion aren t you ? <EOS>
#
# > je suis femme au foyer .
# = i am a housewife .
# < i am a housewife . <EOS>
#
# > vous etes cruel .
# = you re cruel .
# < you re very talented . <EOS>
#
# > elles sont toutes a moi .
# = they re all mine .
# < they re all mine . <EOS>
#
# > tu es un menteur .
# = you re a liar .
# < you re a filthy liar . <EOS>
#
# > je suis toujours content .
# = i m always happy .
# < i m always happy . <EOS>
#
# > vous allez me manquer .
# = i m going to miss you .
# < you re going to miss me . <EOS>
#
# Iter: 45
# Learning Rate: 1
# Time: 0h 11m 30s
# Train Loss: 0.10632007490930225
#
# > j ai faim et soif .
# = i m hungry and thirsty .
# < i am hungry and thirsty . <EOS>
#
# > je me fais des soucis pour sa securite .
# = i am concerned for her safety .
# < i am concerned for her safety . <EOS>
#
# > je suis tres fier de mon pere .
# = i m very proud of my father .
# < i m very proud of my father . <EOS>
#
# > t es libre d y aller .
# = you re free to go .
# < you re free to go . <EOS>
#
# > elles sont trop grosses .
# = they re too fat .
# < they are too busy . <EOS>
#
# > elle n est pas sans argent .
# = she s not penniless .
# < she s not penniless . <EOS>
#
# > vous n etes pas contrarie si ?
# = you re not upset are you ?
# < you re not upset are you ? <EOS>
#
# > je suis content que ca vous rende heureuses .
# = i m glad that makes you happy .
# < i m glad that makes you happy . <EOS>
#
# > elle peint sa chambre en blanc .
# = she s painting her room white .
# < she s painting her room white . <EOS>
#
# > il se fait vieux .
# = he is getting old .
# < he s getting old . <EOS>
#
# Iter: 46
# Learning Rate: 1
# Time: 0h 11m 45s
# Train Loss: 0.10123114849711516
#
# > vous etes tres occupe .
# = you re very busy .
# < you re very busy . <EOS>
#
# > nous ne sommes pas ici pour vous arreter .
# = we are not here to arrest you .
# < we are not here to arrest you . <EOS>
#
# > je ne pratique pas la divination .
# = i m not a psychic .
# < i m not a psychic . <EOS>
#
# > nous sommes encore vulnerables .
# = we re still vulnerable .
# < we re still vulnerable . <EOS>
#
# > je ne suis pas vraiment un expert .
# = i m not really an expert .
# < i m not really an expert . <EOS>
#
# > il est nerveux et facilement effraye .
# = he s nervous and gets scared easily .
# < he s nervous and scared easily . <EOS>
#
# > je cherche mon telephone mobile .
# = i m looking for my cellphone .
# < i m looking for my cellphone out . <EOS>
#
# > tu es un type genial .
# = you re a wonderful guy .
# < you re a wonderful guy . <EOS>
#
# > j y suis accoutume .
# = i m used to it .
# < i m used to used . <EOS>
#
# > on est fauches .
# = we re broke .
# < we re broke . <EOS>
#
# Iter: 47
# Learning Rate: 1
# Time: 0h 12m 1s
# Train Loss: 0.09643055261773624
#
# > il bataille encore avec les croyances religieuses .
# = he is still grappling with religious beliefs .
# < he is still grappling with religious beliefs . <EOS>
#
# > je ne suis pas en train de compter .
# = i m not counting .
# < i m not counting . <EOS>
#
# > nous sommes tous occupes .
# = we re all busy .
# < we re all busy . <EOS>
#
# > tu reussiras sans aucun doute quoique tu fasses .
# = you are sure to succeed whatever you do .
# < you are sure to succeed whatever you know . <EOS>
#
# > ils sont tous decedes .
# = they re all dead .
# < they re all dead . <EOS>
#
# > je suis sur de son nom .
# = i m sure about his name .
# < i m sure about his name . <EOS>
#
# > elle l a vu briser la fenetre .
# = she saw him break the window .
# < she saw him break the window . <EOS>
#
# > je demande ce que vous en pensez .
# = i m asking what you think .
# < i m asking what you think . <EOS>
#
# > il porte des gants .
# = he is wearing gloves .
# < he is wearing gloves . <EOS>
#
# > elle a la baraka .
# = she s on a roll .
# < she s on a roll . <EOS>
#
# Iter: 48
# Learning Rate: 1
# Time: 0h 12m 16s
# Train Loss: 0.0896538587817596
#
# > c est un jeune directeur plein de talent .
# = he s a talented young director .
# < he s a talented young director . <EOS>
#
# > j oublie toujours les noms des gens .
# = i m always forgetting people s names .
# < i m always forgetting people s names . <EOS>
#
# > je ne suis pas bon a ca .
# = i m not good at it .
# < i m not good at this . <EOS>
#
# > il est japonais de naissance .
# = he is japanese by birth .
# < he is japanese by birth . <EOS>
#
# > nous sommes seules .
# = we re on our own .
# < we re alone . <EOS>
#
# > je suis un homme prudent .
# = i m a careful man .
# < i m a careful man . <EOS>
#
# > tu es dedans jusqu au cou .
# = you re in over your head .
# < you are in over your head . <EOS>
#
# > il est prof d anglais .
# = he is a teacher of english .
# < he is a teacher of english . <EOS>
#
# > vous etes soucieuses n est ce pas ?
# = you re worried aren t you ?
# < you re worried aren t you ? <EOS>
#
# > ce sont des etudiantes .
# = they re students .
# < they re students . <EOS>
#
# Iter: 49
# Learning Rate: 1
# Time: 0h 12m 31s
# Train Loss: 0.08538316832003691
#
# > je suis content que ca vous rende heureux .
# = i m glad that makes you happy .
# < i m glad that makes you happy . <EOS>
#
# > je ne suis plus inspiree .
# = i m not inspired anymore .
# < i m not inspired anymore . <EOS>
#
# > je n ai pas faim du tout .
# = i m not even a little hungry .
# < i m not hungry at all . <EOS>
#
# > je suis musicienne .
# = i m a musician .
# < i m a musician . <EOS>
#
# > il est capable de nager tres vite .
# = he is able to swim very fast .
# < he is able to swim very fast . <EOS>
#
# > je me fais trop vieux pour ce travail .
# = i m getting too old for this job .
# < i m getting too old for this job . <EOS>
#
# > je suis prete a te suivre .
# = i am ready to follow you .
# < i am ready to follow you . <EOS>
#
# > je commence des ce soir .
# = i am starting this evening .
# < i am starting this evening . <EOS>
#
# > vous etes durs .
# = you re tough .
# < you re tough . <EOS>
#
# > vous etes celle la .
# = you are the one .
# < you re the one now . <EOS>
#
# Iter: 50
# Learning Rate: 1
# Time: 0h 12m 47s
# Train Loss: 0.08160398207368014
#
# > vous gaspillez notre temps a tous les deux .
# = you re wasting both of our time .
# < you re wasting both of our time . <EOS>
#
# > il est frais emoulu de l universite .
# = he s fresh out of college .
# < he is fresh from college . <EOS>
#
# > je paie .
# = i m buying .
# < i m buying . <EOS>
#
# > nous sommes desoles pour le derangement .
# = we are sorry for the inconvenience .
# < we are sorry for the inconvenience . <EOS>
#
# > je recherche un assistant .
# ...
# < you re not in charge . <EOS>
#
# > ils sont chretiens .
# = they re christians .
# < they are christians . <EOS>
#
# > nous ne sommes pas en forme .
# = we re not fit .
# < we re not fit . <EOS>
#
# > nous n allons pas y parvenir .
# = we re not going to make it .
# < we re not going to make it . <EOS>
#
# > je suis en premier .
# = i m first .
# < i m first . <EOS>
#
# > il est sensible a la critique .
# = he is sensitive to criticism .
# < he is sensitive to criticism . <EOS>
#
# > nous sommes a court d argent .
# = we are short of money .
# < we re short of money . <EOS>
#
# > nous sommes une famille .
# = we are a family .
# < we re a family of two . <EOS>
#
# > tu es allemand n est ce pas ?
# = you re german right ?
# < you re german aren t you ? <EOS>
#
# > je suis content que tom soit la .
# = i m glad that tom is here .
# < i m glad that tom is here . <EOS>
#
# Iter: 86
# Learning Rate: 1
# Time: 0h 22m 3s
# Train Loss: 0.03564866546948052
#
# > je suis en train de cuire du pain .
# = i am baking bread .
# < i am baking bread . <EOS>
#
# > je ne suis pas sure d aimer ca .
# = i m not sure i like this .
# < i m not sure i like this . <EOS>
#
# > j en ai fini de toi .
# = i m done with you .
# < i m done listening of you . <EOS>
#
# > je ne suis pas un heros .
# = i m not a hero .
# < i m not a hero . <EOS>
#
# > tu es tiree d affaire .
# = you re off the hook .
# < you re off the hook . <EOS>
#
# > t es sympa .
# = you re cool .
# < you re nice a nice feller . <EOS>
#
# > je suis en train d apprendre le basque .
# = i m learning basque .
# < i m learning basque . <EOS>
#
# > c est le plus grand artiste vivant .
# = he is the greatest living artist .
# < he is the greatest living artist . <EOS>
#
# > je suis egalement pensionnee .
# = i m retired too .
# < i m retired too . <EOS>
#
# > tu es si mechant .
# = you re so mean .
# < you re so mean . <EOS>
#
# Iter: 87
# Learning Rate: 1
# Time: 0h 22m 19s
# Train Loss: 0.034779230611455596
#
# > vous etes responsable de ce que vous faites .
# = you are responsible for what you do .
# < you are responsible for what you do . <EOS>
#
# > nous sommes sournoises .
# = we re sneaky .
# < we re being last . <EOS>
#
# > vous n allez pas le croire .
# = you re not going to believe this .
# < you re not going to believe this . <EOS>
#
# > n avoir qu un ami me convient .
# = i m ok with having just one friend .
# < i m ok with having just one friend . <EOS>
#
# > nous avons juste peur .
# = we re just scared .
# < we re just scared . <EOS>
#
# > je suis tout seul .
# = i m all alone .
# < i m all alone . <EOS>
#
# > je suis presque prete .
# = i am almost ready .
# < i m about ready . <EOS>
#
# > elle est fiere de ses enfants .
# = she is proud of her children .
# < she is proud of her children . <EOS>
#
# > ils sont au jardin .
# = they re in the garden .
# < they re in the garden . <EOS>
#
# > il est cool pas vrai ?
# = he is cool isn t he ?
# < he is cool isn t he ? <EOS>
#
# Iter: 88
# Learning Rate: 1
# Time: 0h 22m 34s
# Train Loss: 0.03491700995519333
#
# > j ai une mauvaise impression .
# = i m getting a bad feeling .
# < i m getting a bad feeling . <EOS>
#
# > vous etes libre .
# = you re free .
# < you re free . <EOS>
#
# > j en ai marre de ce temps humide .
# = i m fed up with this wet weather .
# < i m fed up with this wet weather . <EOS>
#
# > elles sont toutes coupables .
# = they re all guilty .
# < they re all guilty . <EOS>
#
# > vous me critiquez sans cesse !
# = you re always criticizing me !
# < you re always criticizing me ! <EOS>
#
# > nous ne sommes pas coupables .
# = we re not guilty .
# < we re not guilty . <EOS>
#
# > vous n etes pas mariee si ?
# = you re not married are you ?
# < you re not married are you ? <EOS>
#
# > tu es fort elegant .
# = you re very stylish .
# < you re very sophisticated . <EOS>
#
# > je reviens a l essentiel .
# = i m just getting back to basics .
# < i m just getting back to basics . <EOS>
#
# > elle ressemble beaucoup a sa mere .
# = she is very much like her mother .
# < she is very much like her mother . <EOS>
#
# Iter: 89
# Learning Rate: 1
# Time: 0h 22m 50s
# Train Loss: 0.03421831862461914
#
# > je suis un peu decu .
# = i m a little disappointed .
# < i m a little disappointed . <EOS>
#
# > j essaie de vous parler .
# = i m trying to talk to you .
# < i m trying to talk to you . <EOS>
#
# > nous sommes trop vieux .
# = we re too old .
# < we re too old . <EOS>
#
# > elles sont differentes .
# = they re different .
# < they are different . <EOS>
#
# > vous etes tres religieuse n est ce pas ?
# = you re very religious aren t you ?
# < you re very religious aren t you ? <EOS>
#
# > ce n est plus un enfant .
# = he is no longer a child .
# < he is no longer a child . <EOS>
#
# > je derange .
# = i m interfering .
# < i m giving . <EOS>
#
# > nous nous en approchons .
# = we re getting close .
# < we re getting close . <EOS>
#
# > je suis en bonne sante .
# = i m healthy .
# < i m in good health . <EOS>
#
# > mieux vaut tard que jamais .
# = you re never too old to learn .
# < you re never too old to learn . <EOS>
#
# Iter: 90
# Learning Rate: 1
# Time: 0h 23m 5s
# Train Loss: 0.0338429095518419
#
# > il projette de lancer son entreprise .
# = he is planning to launch his business .
# < he is planning to launch his business . <EOS>
#
# > il bout de colere .
# = he is boiling with rage .
# < he is boiling with rage . <EOS>
#
# > je ne sais pas bien nager .
# = i am poor at swimming .
# < i m bad at swimming . <EOS>
#
# > vous etes trop polies .
# = you re too polite .
# < you re too polite . <EOS>
#
# > je suis farouchement oppose a un compromis .
# = i m strongly opposed to a compromise .
# < i m strongly opposed to a compromise . <EOS>
#
# > maintenant j ai des ennuis .
# = i m in trouble now .
# < i m in trouble now . <EOS>
#
# > je vais a paris a l automne .
# = i m going to paris in the fall .
# < i m going to paris in the fall . <EOS>
#
# > il est cruel et sans c ur .
# = he s cruel and heartless .
# < he s cruel and heartless . <EOS>
#
# > il est recherche par la police .
# = he is hunted by the police .
# < he is hunted by the police . <EOS>
#
# > nous ne sortons pas ensemble .
# = we re not dating .
# < we re not dating . <EOS>
#
# Iter: 91
# Learning Rate: 1
# Time: 0h 23m 21s
# Train Loss: 0.03327602931258328
#
# > vous n etes pas tres amusante .
# = you re not very funny .
# < you re not very funny . <EOS>
#
# > tu es tellement idiot !
# = you are so stupid .
# < you are so stupid . <EOS>
#
# > tu gaspilles du temps .
# = you re wasting time .
# < you re wasting time . <EOS>
#
# > nous ne sommes pas apparentes .
# = we aren t related .
# < we re not related . <EOS>
#
# > je suis celle qui l a rencontre .
# = i m the one who met him .
# < i m the one who met him . <EOS>
#
# > tu regardes tout le temps la tele .
# = you are watching tv all the time .
# < you are watching tv all the time . <EOS>
#
# > tu n as pas tort du tout .
# = you are not at all wrong .
# < you are not at all wrong . <EOS>
#
# > quel imbecile tu es !
# = you re such an idiot !
# < you re such an idiot ! <EOS>
#
# > je ne vais pas gaspiller mon argent .
# = i m not going to waste my money .
# < i m not going to waste my money . <EOS>
#
# > tu as le meme age que ma copine .
# = you re the same age as my girlfriend .
# < you re the same age as my girlfriend . <EOS>
#
# Iter: 92
# Learning Rate: 1
# Time: 0h 23m 36s
# Train Loss: 0.033740792782218344
#
# > je ne suis pas jalouse .
# = i m not jealous .
# < i m not as busy . <EOS>
#
# > je suis tres attiree par toi .
# = i m very drawn to you .
# < i m very drawn to you . <EOS>
#
# > je suis en train de me noyer .
# = i m drowning .
# < i m drowning . <EOS>
#
# > elle est tres desireuse de te rencontrer .
# = she is anxious to meet you .
# < she is anxious to meet you . <EOS>
#
# > nous sommes cernes .
# = we re surrounded .
# < we re surrounded . <EOS>
#
# > il est la pour quelques jours .
# = he is there for a few days .
# < he is there for a few days . <EOS>
#
# > je suis curieux .
# = i m curious .
# < i am curious . <EOS>
#
# > il est nerveusement use .
# = he s a nervous wreck .
# < he s a nervous wreck . <EOS>
#
# > j en suis certain .
# = i m sure .
# < i m sure . <EOS>
#
# > elle est belle comme sa mere .
# = she is beautiful like her mother .
# < she is beautiful like her mother . <EOS>
#
# Iter: 93
# Learning Rate: 1
# Time: 0h 23m 51s
# Train Loss: 0.03322657452684392
#
# > je suis ami avec lui .
# = i m friends with him .
# < i m friends with him with him . <EOS>
#
# > tu es tres emotive .
# = you re very emotional .
# < you re very emotional . <EOS>
#
# > c est vous l aine .
# = you re the oldest .
# < you re the oldest . <EOS>
#
# > tu es fort emotive .
# = you re very emotional .
# < you re very emotional . <EOS>
#
# > vous etes tres grande .
# = you re very tall .
# < you re very tall . <EOS>
#
# > vous etes puissant .
# = you re powerful .
# < you re powerful . <EOS>
#
# > nous sommes tetus .
# = we re stubborn .
# < we re careful . <EOS>
#
# > vous etes matinale .
# = you re early .
# < you re at the teacher . <EOS>
#
# > les etudes sociales m interessent beaucoup .
# = i m very interested in social studies .
# < i m very interested in social studies . <EOS>
#
# > je ramene une pizza a la maison .
# = i m bringing home a pizza .
# < i m bringing home a pizza . <EOS>
#
# Iter: 94
# Learning Rate: 1
# Time: 0h 24m 7s
# Train Loss: 0.03363779185053483
#
# > vous etes un traitre .
# = you re a traitor .
# < you re a traitor . <EOS>
#
# > tu as parfaitement raison .
# = you re absolutely right .
# < you re totally right . <EOS>
#
# > vous etes celui qui a plante cet arbre .
# = you re the one who planted that tree .
# < you re the one who planted that tree . <EOS>
#
# > il ne craint pas de mourir .
# = he isn t afraid to die .
# < he isn t afraid to die . <EOS>
#
# > vous ne regardez pas .
# = you aren t looking .
# < you aren t t help . <EOS>
#
# > c est un homme dur en affaire .
# = he is a hard man to deal with .
# < he is a hard man to deal with . <EOS>
#
# > je suis en train de faire mes devoirs .
# = i m doing my homework .
# < i m doing my homework . <EOS>
#
# > nous sommes fermes le lundi .
# = we re closed on mondays .
# < we re closed on mondays . <EOS>
#
# > je suis sur qu ils vont gagner .
# = i m sure they ll win .
# < i m sure they ll win . <EOS>
#
# > je suis pret pour demain .
# = i m ready for tomorrow .
# < i m ready for tomorrow . <EOS>
#
# Iter: 95
# Learning Rate: 1
# Time: 0h 24m 22s
# Train Loss: 0.033666266504002396
#
# > tu es hors de controle .
# = you re out of control .
# < you re out of control . <EOS>
#
# > nous discuterons du probleme demain .
# = we re going to discuss the problem tomorrow .
# < we re going to discuss the problem tomorrow . <EOS>
#
# > j utilise cette tasse .
# = i m using that cup .
# < i m using that cup . <EOS>
#
# > nous sommes au milieu d amis .
# = we re among friends .
# < we re among friends . <EOS>
#
# > je suis desolee d avoir rompu ma promesse .
# = i m sorry i broke my promise .
# < i m sorry i broke my promise . <EOS>
#
# > c est un artiste ne .
# = he is a born artist .
# < he is a born artist . <EOS>
#
# > elle est enceinte .
# = she s pregnant .
# < she s pregnant . <EOS>
#
# > il a des problemes .
# = he is in trouble .
# < he is in trouble of problems . <EOS>
#
# > on dit qu il est riche .
# = he is said to be rich .
# < he is said to be rich . <EOS>
#
# > c est une femme d une grande beaute .
# = she is a woman of great beauty .
# < she is a woman of great beauty . <EOS>
#
# Iter: 96
# Learning Rate: 1
# Time: 0h 24m 38s
# Train Loss: 0.03232321906792107
#
# > je suis heureuse que vous veniez .
# = i m glad you re coming .
# < i m glad you re coming . <EOS>
#
# > nous sommes en route .
# = we re on our way .
# < we re on our way . <EOS>
#
# > vous etes fort comprehensive .
# = you re very understanding .
# < you re very understanding . <EOS>
#
# > je meurs de faim !
# = i m starving !
# < i m very hungry . <EOS>
#
# > tous les deux sont celibataires .
# = they are both unmarried .
# < they are both unmarried . <EOS>
#
# > je suis amoureux de vous .
# = i m in love with you .
# < i m in love with you . <EOS>
#
# > ce sont tous deux des collegues a moi .
# = they are both colleagues of mine .
# < they are both colleagues of mine . <EOS>
#
# > il est prevu que je dejeune avec lui .
# = i m scheduled to have lunch with him .
# < i m scheduled to have lunch with him . <EOS>
#
# > je crains que non .
# = i m afraid not .
# < i m afraid not . <EOS>
#
# > c est une personne tres attentionnee .
# = he is a very thoughtful person .
# < he is a very thoughtful person . <EOS>
#
# Iter: 97
# Learning Rate: 1
# Time: 0h 24m 53s
# Train Loss: 0.032135707130567126
#
# > je n en suis plus sure .
# = i m not sure anymore .
# < i m not sure anymore . <EOS>
#
# > je suis ambidextre .
# = i m ambidextrous .
# < i m ambidextrous . <EOS>
#
# > ils sont loyaux envers leur maitre .
# = they are loyal to their master .
# < they are loyal to their master . <EOS>
#
# > mon travail ne me plait pas .
# = i m not happy with my job .
# < i m not happy with my job . <EOS>
#
# > il est amoureux d elle .
# = he is in love with her .
# < he is in love with her . <EOS>
#
# > vous etes toutes contentes .
# = you re all happy .
# < you re all happy . <EOS>
#
# > je suis vraiment desole de t avoir derange .
# = i m very sorry to have troubled you .
# < i m very sorry to have troubled you . <EOS>
#
# > il est a son cote .
# = he s at her side .
# < he s at her side . <EOS>
#
# > je suis fatigue de faire la queue .
# = i m tired of waiting in line .
# < i m tired of waiting in line . <EOS>
#
# > je suis la voisine de tom .
# = i m tom s neighbor .
# < i m tom s neighbor . <EOS>
#
# Iter: 98
# Learning Rate: 1
# Time: 0h 25m 9s
# Train Loss: 0.032005363065897144
#
# > elle n est pas d humeur .
# = she s not in the mood .
# < she s not in the mood . <EOS>
#
# > tu es tres intelligent .
# = you re very intelligent .
# < you re very intelligent . <EOS>
#
# > je n en peux plus de combattre .
# = i m sick of fighting .
# < i m sick of fighting . <EOS>
#
# > vous etes hors de controle .
# = you re out of control .
# < you are out of control . <EOS>
#
# > je suis un vendeur .
# = i m a salesperson .
# < i m a salesman . <EOS>
#
# > il est fou de baseball .
# = he is crazy about baseball .
# < he is crazy about baseball . <EOS>
#
# > je vais jouer au tennis ce soir .
# = i m going to play tennis this evening .
# < i m going to play tennis this evening . <EOS>
#
# > je vais envoyer de l argent a tom .
# = i m going to send tom some money .
# < i m going to send tom some money . <EOS>
#
# > nous sommes toutes celibataires .
# = we re all single .
# < we re all single . <EOS>
#
# > je suis en faveur de ta proposition .
# = i am in favor of your proposal .
# < i am in favor of your proposal . <EOS>
#
# Iter: 99
# Learning Rate: 1
# Time: 0h 25m 24s
# Train Loss: 0.03235541345342208
#
# > vous etes incroyablement talentueuse .
# = you re incredibly talented .
# < you re incredibly talented . <EOS>
#
# > je suis sur que tout ira bien .
# = i m sure everything will be fine .
# < i m sure everything will be fine . <EOS>
#
# > tu es splendide .
# = you are gorgeous .
# < you are gorgeous . <EOS>
#
# > nous sommes tellement contents de t avoir ici !
# = we re so glad to have you here .
# < we re so glad to have you here . <EOS>
#
# > je vais y repenser encore une fois .
# = i m going to reconsider it .
# < i m going to reconsider it . <EOS>
#
# > je suis ponctuel .
# = i m punctual .
# < i m punctual . <EOS>
#
# > je commence a me sentir desespere .
# = i m starting to feel desperate .
# < i m starting to feel desperate . <EOS>
#
# > elle est trop bruyante .
# = she s too loud .
# < she s too loud . <EOS>
#
# > vous etes fascinante .
# = you re fascinating .
# < you re a traitor . <EOS>
#
# > on ne veut pas de vous ici .
# = you re not wanted here .
# < you re not wanted here . <EOS>
#
# Iter: 100
# Learning Rate: 1
# Time: 0h 25m 40s
# Train Loss: 0.03097403944124748
#
# > tu es fort solitaire .
# = you re very lonely .
# < you re very lonely . <EOS>
#
# > nous sommes des nouvelles venues .
# = we re newcomers .
# < we re newcomers . <EOS>
#
# > elle est extremement sensible au froid .
# = she is exceedingly sensitive to the cold .
# < she is exceedingly sensitive to the cold . <EOS>
#
# > je suis ici pour voir le gerant .
# = i m here to see the manager .
# < i m here to see the manager . <EOS>
#
# > il se montre difficile avec moi .
# = he is giving me a hard time .
# < he is giving me a hard time . <EOS>
#
# > je suis interesse par l histoire japonaise .
# = i am interested in japanese history .
# < i am interested in japanese history . <EOS>
#
# > je suis retraite .
# = i m retired .
# < i m retired too . <EOS>
#
# > je ne suis pas medecin mais enseignant .
# = i m not a doctor but a teacher .
# < i m not a doctor but a teacher . <EOS>
#
# > nous ne sommes pas habillees .
# = we re not dressed .
# < we re not dressed . <EOS>
#
# > je travaille dans ma ferme .
# = i m a farmer .
# < i m a farmer . <EOS>

# %%
from google.colab import files
files.download('file_name.ext')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-3b1482b59ec7> in <module>()
#       1 from google.colab import files
# ----> 2 files.download('file_name.ext')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in download(filename)
#     141       raise OSError(msg)
#     142     else:
# --> 143       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     144
#     145   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: file_name.ext

# %%
ls
# Out:
# eng-fra.txt
# sample_data/
# testdata.orig_trim.10_vocab.20000_directions.2_layers.2_hidden.440_dropout.0.2_learningrate.1_batch.32_epochs.100.png
# testdata.orig_trim.10_vocab.20000_directions.2_layers.2_hidden.440_dropout.0.2_learningrate.1_batch.32_epochs.100.txt
